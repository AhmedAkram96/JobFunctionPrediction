# %% [markdown]
# # Jobs titles and functions Dataset
#
#
#
# Job functions and job titles are very different things. A job title is essentially
# the name of a position within an organization filled by an employee. Job
# function is the routine set of tasks or activities undertaken by a person in
# that position. An employee's title and function are often closely related,
# though not all job functions are clear based on title alone.
#
#
# ### So, in this notebook we are trying to build a system to recommend the job functions in which an employee with a specific job title can work

# %% [markdown]
# # 1. Data Engineering

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

from keras.models import Sequential
from keras import layers
from keras.utils import to_categorical
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.externals import joblib
import pickle

# %% [markdown]
#  At first, We start by fetching and inspecting the dataset

# %%
#Inspecting the data
jobs_data = pd.read_csv("jobs_data.csv")
jobs_data.head(10)
# Out:
#    Unnamed: 0                                           title  \
# 0           0                        Full Stack PHP Developer
# 1           1         CISCO Collaboration Specialist Engineer
# 2           2                   Senior Back End-PHP Developer
# 3           3                                     UX Designer
# 4           4                             Java Technical Lead
# 5           5                      Technical Support Engineer
# 6           6                            Senior iOS Developer
# 7           7                             Mechanical Engineer
# 8           8  Real Estate Sales Specialist - 10th of Ramadan
# 9           9                                School Principal
#
#                                          jobFunction  \
# 0  ['Engineering - Telecom/Technology', 'IT/Softw...
# 1  ['Installation/Maintenance/Repair', 'IT/Softwa...
# 2  ['Engineering - Telecom/Technology', 'IT/Softw...
# 3  ['Creative/Design/Art', 'IT/Software Developme...
# 4  ['Engineering - Telecom/Technology', 'IT/Softw...
# 5  ['IT/Software Development', 'Engineering - Tel...
# 6  ['Engineering - Telecom/Technology', 'IT/Softw...
# 7            ['Engineering - Mechanical/Electrical']
# 8                                   ['Sales/Retail']
# 9  ['Education/Teaching', 'Administration', 'Oper...
#
#                                             industry
# 0  ['Computer Software', 'Marketing and Advertisi...
# 1                ['Information Technology Services']
# 2       ['Computer Software', 'Computer Networking']
# 3  ['Computer Software', 'Information Technology ...
# 4  ['Computer Software', 'Information Technology ...
# 5  ['Information Technology Services', 'Computer ...
# 6  ['Information Technology Services', 'Graphic D...
# 7  ['Architectural and Design Services', 'Enginee...
# 8                ['Real Estate/Property Management']
# 9                                      ['Education']

# %% [markdown]
# As you can see above, We have to rename the Unnamed column to be the ID and the index of this dataset

# %%
jobs_data = jobs_data.rename(columns={"Unnamed: 0": "ID"})
jobs_data
# Out:
#           ID                                              title  \
# 0          0                           Full Stack PHP Developer
# 1          1            CISCO Collaboration Specialist Engineer
# 2          2                      Senior Back End-PHP Developer
# 3          3                                        UX Designer
# 4          4                                Java Technical Lead
# 5          5                         Technical Support Engineer
# 6          6                               Senior iOS Developer
# 7          7                                Mechanical Engineer
# 8          8     Real Estate Sales Specialist - 10th of Ramadan
# 9          9                                   School Principal
# 10        10                        Senior Sales Representative
# 11        11                                         Accountant
# 12        12                             Indoor Sales Executive
# 13        13                     PHP Full-Stack - Joomla Expert
# 14        14                          English Teacher Assistant
# 15        15                              Marketing Coordinator
# 16        16                          Senior Business Developer
# 17        17                           Senior Website Developer
# 18        18                                   Chief Accountant
# 19        19                         Senior Front-End Developer
# 20        20               Sales Account Manager - Google Cloud
# 21        21                          Senior Back-End Developer
# 22        22                                       Video Editor
# 23        23                       Digital Marketing Specialist
# 24        24               Mechanical Technical Office Engineer
# 25        25                                     Sales Engineer
# 26        26                   German Teacher - American School
# 27        27                                 Personal Assistant
# 28        28                              Sales Account Manager
# 29        29                        Sales Coordinator/Telesales
# ...      ...                                                ...
# 10840  10840        Production Manager - PE Film Extrusion line
# 10841  10841                          Customer Support Engineer
# 10842  10842                               Nursery Psychologist
# 10843  10843                         Managing Director - Kuwait
# 10844  10844                                     Office Manager
# 10845  10845                   Senior Software Business Analyst
# 10846  10846                           Public Relations Manager
# 10847  10847            Property Sales Consultant - Real Estate
# 10848  10848                            Real Estate Sales Agent
# 10849  10849                          Web Designer - Alexandria
# 10850  10850                         Senior Marketing Executive
# 10851  10851          Outdoor Sales Representative - Alexandria
# 10852  10852                            Front-End Web Developer
# 10853  10853                                    Sales Executive
# 10854  10854                                          Secretary
# 10855  10855                                        QA Engineer
# 10856  10856                          Senior .Net Web Developer
# 10857  10857                                   Property Advisor
# 10858  10858                                         Pharmacist
# 10859  10859    Arabic KG Teacher - مُدرسة لغة عربية رياض أطفال
# 10860  10860                     Receptionist, Front Desk Clerk
# 10861  10861                                      iOS Developer
# 10862  10862                                    Sales Executive
# 10863  10863  Solution Developer / Back-End Developer Subjec...
# 10864  10864                               Marketing Specialist
# 10865  10865                                     Odoo Developer
# 10866  10866                  Senior PHP Developer - Alexandria
# 10867  10867  Sales & Account Manager (Real Estate / Medical...
# 10868  10868  Technical and Network Support Engineer - Alexa...
# 10869  10869                              Senior Java Developer
#
#                                              jobFunction  \
# 0      ['Engineering - Telecom/Technology', 'IT/Softw...
# 1      ['Installation/Maintenance/Repair', 'IT/Softwa...
# 2      ['Engineering - Telecom/Technology', 'IT/Softw...
# 3      ['Creative/Design/Art', 'IT/Software Developme...
# 4      ['Engineering - Telecom/Technology', 'IT/Softw...
# 5      ['IT/Software Development', 'Engineering - Tel...
# 6      ['Engineering - Telecom/Technology', 'IT/Softw...
# 7                ['Engineering - Mechanical/Electrical']
# 8                                       ['Sales/Retail']
# 9      ['Education/Teaching', 'Administration', 'Oper...
# 10     ['Sales/Retail', 'Marketing/PR/Advertising', '...
# 11                                ['Accounting/Finance']
# 12               ['Sales/Retail', 'Creative/Design/Art']
# 13     ['IT/Software Development', 'Engineering - Tel...
# 14                                ['Education/Teaching']
# 15     ['Media/Journalism/Publishing', 'Marketing/PR/...
# 16          ['Marketing/PR/Advertising', 'Sales/Retail']
# 17     ['IT/Software Development', 'Engineering - Tel...
# 18                                ['Accounting/Finance']
# 19     ['Engineering - Telecom/Technology', 'IT/Softw...
# 20     ['IT/Software Development', 'Sales/Retail', 'E...
# 21     ['IT/Software Development', 'Engineering - Tel...
# 22     ['Creative/Design/Art', 'Media/Journalism/Publ...
# 23                          ['Marketing/PR/Advertising']
# 24               ['Engineering - Mechanical/Electrical']
# 25           ['IT/Software Development', 'Sales/Retail']
# 26                                ['Education/Teaching']
# 27                                    ['Administration']
# 28                                      ['Sales/Retail']
# 29     ['Administration', 'Operations/Management', 'S...
# ...                                                  ...
# 10840  ['Manufacturing/Production', 'Engineering - Me...
# 10841  ['Engineering - Telecom/Technology', 'Engineer...
# 10842                             ['Education/Teaching']
# 10843                                   ['Sales/Retail']
# 10844              ['Administration', 'Human Resources']
# 10845  ['IT/Software Development', 'Analyst/Research'...
# 10846  ['Marketing/PR/Advertising', 'Media/Journalism...
# 10847                                   ['Sales/Retail']
# 10848                                   ['Sales/Retail']
# 10849  ['Engineering - Telecom/Technology', 'IT/Softw...
# 10850  ['Marketing/PR/Advertising', 'Media/Journalism...
# 10851       ['Customer Service/Support', 'Sales/Retail']
# 10852  ['Engineering - Telecom/Technology', 'IT/Softw...
# 10853                                   ['Sales/Retail']
# 10854                                 ['Administration']
# 10855             ['IT/Software Development', 'Quality']
# 10856  ['IT/Software Development', 'Engineering - Tel...
# 10857                                   ['Sales/Retail']
# 10858                                 ['Pharmaceutical']
# 10859                             ['Education/Teaching']
# 10860  ['Medical/Healthcare', 'Hospitality/Hotels/Foo...
# 10861  ['IT/Software Development', 'Engineering - Tel...
# 10862                                   ['Sales/Retail']
# 10863  ['Engineering - Telecom/Technology', 'IT/Softw...
# 10864  ['Marketing/PR/Advertising', 'Media/Journalism...
# 10865  ['IT/Software Development', 'Engineering - Tel...
# 10866  ['Engineering - Telecom/Technology', 'IT/Softw...
# 10867  ['Business Development', 'Sales/Retail', 'Cust...
# 10868  ['Installation/Maintenance/Repair', 'Engineeri...
# 10869  ['IT/Software Development', 'Engineering - Tel...
#
#                                                 industry
# 0      ['Computer Software', 'Marketing and Advertisi...
# 1                    ['Information Technology Services']
# 2           ['Computer Software', 'Computer Networking']
# 3      ['Computer Software', 'Information Technology ...
# 4      ['Computer Software', 'Information Technology ...
# 5      ['Information Technology Services', 'Computer ...
# 6      ['Information Technology Services', 'Graphic D...
# 7      ['Architectural and Design Services', 'Enginee...
# 8                    ['Real Estate/Property Management']
# 9                                          ['Education']
# 10                         ['Marketing and Advertising']
# 11                                         ['Education']
# 12     ['Architectural and Design Services', 'Manufac...
# 13                   ['Information Technology Services']
# 14                                         ['Education']
# 15                         ['Marketing and Advertising']
# 16     ['Marketing and Advertising', 'Computer Softwa...
# 17                    ['Insurance', 'Computer Software']
# 18                                         ['Education']
# 19     ['Information Technology Services', 'Internet/...
# 20     ['Computer Software', 'Information Technology ...
# 21                                         ['Education']
# 22                         ['Marketing and Advertising']
# 23                         ['Marketing and Advertising']
# 24     ['Architectural and Design Services', 'Constru...
# 25     ['Information Technology Services', 'Consultin...
# 26                                         ['Education']
# 27     ['Real Estate/Property Management', 'Business ...
# 28     ['Logistics and Supply Chain', 'Translation an...
# 29                   ['Information Technology Services']
# ...                                                  ...
# 10840  ['Manufacturing', 'Publishing and Printing', '...
# 10841  ['Computer Software', 'Information Technology ...
# 10842                                      ['Education']
# 10843                ['Information Technology Services']
# 10844                                  ['Manufacturing']
# 10845                ['Information Technology Services']
# 10846           ['Human Resources', 'Computer Software']
# 10847                ['Real Estate/Property Management']
# 10848                ['Real Estate/Property Management']
# 10849  ['Internet/E-commerce', 'Information Technolog...
# 10850  ['Marketing and Advertising', 'Real Estate/Pro...
# 10851  ['Graphic Design', 'Computer Software', 'Marke...
# 10852  ['Computer Software', 'Healthcare and Medical ...
# 10853  ['Information Technology Services', 'Translati...
# 10854                      ['Marketing and Advertising']
# 10855      ['Engineering Services', 'Computer Software']
# 10856                              ['Computer Software']
# 10857                ['Real Estate/Property Management']
# 10858  ['Pharmaceuticals', 'Health, Wellness and Fitn...
# 10859                                      ['Education']
# 10860  ['Hospitality/Hotels', 'Healthcare and Medical...
# 10861  ['Computer Software', 'Information Technology ...
# 10862         ['Marketing and Advertising', 'Furniture']
# 10863                              ['Computer Software']
# 10864  ['Marketing and Advertising', 'Public Relation...
# 10865  ['Real Estate/Property Management', 'Manufactu...
# 10866                ['Information Technology Services']
# 10867  ['Real Estate/Property Management', 'Retail', ...
# 10868  ['Computer Software', 'Education', 'Healthcare...
# 10869                ['Information Technology Services']
#
# [10870 rows x 4 columns]

# %% [markdown]
# ##### After inspecting the dataset, We noticed  2 repeated  job functions  which are :
#
#
#  ['IT/Software Development', 'Engineering - Telecom/Technology']
#
# #####  And
#
#  ['Engineering - Telecom/Technology', 'IT/Software Development']
#
# ##### which are simillar to each other but inverted, So we decided to convert one to the other so they would be the exact same.

# %%
term = "['IT/Software Development', 'Engineering - Telecom/Technology']"
i=0
for job in jobs_data.jobFunction:

    if(job == term):
        jobs_data.jobFunction[i]=  "['Engineering - Telecom/Technology', 'IT/Software Development']"
    i+=1

# %% [markdown]
# During inspecting the dataset, We have Also noticed that maybe morethan 95% of the __titles__ of all data instances that have
# the __['Media/Journalism/Publishing', 'Marketing/PR/Advertising']__ term as a __JobFunction__
# include at least 1 word from a list of keywords : __['marketing' , 'market', 'media' , 'digital' , 'social', 'advertising', 'brand','seo']__
#
# <b>Tip:</b> This is why we decided to change all these titles into 1 unified Title : __"Marketing Specialist"__
# and save all these Keywords in one list.

# %%
term = "['Media/Journalism/Publishing', 'Marketing/PR/Advertising']"
i=0
keywords = []
for jobFunction in jobs_data.jobFunction:  
    if(jobFunction == term): 
        jobs_data.title[i] = "Marketing Specialist"      
    i+=1

# %%
Marketing_Keywords = ['marketing' , 'market', 'media' , 'digital' , 'social', 'advertising', 'brand','seo']

# %% [markdown]
# Simillary, During inspecting the dataset, We have Also noticed that maybe morethan 95% of the __titles__ of all data instances that have
# the __['Sales/Retail']__ term as a __JobFunction__
# include at least 1 word from a list of keywords : __['sales' , 'real estate', 'real' , 'estate' , 'real-estate', 'broker', 'property']__
#
# <b>Tip:</b> This is why we decided to change all these titles into 1 unified Title : __"Sales Consultant"__
# and save all these Keywords in one list.

# %%
term = "['Sales/Retail']"
i=0
keywords = []
for jobFunction in jobs_data.jobFunction:  
    if(jobFunction == term): 
        jobs_data.title[i] = "Sales Consultant"      
    i+=1

# %%
Sales_Keywords = ['sales' , 'real estate', 'real' , 'estate' , 'real-estate', 'broker', 'property']

# %% [markdown]
# Here it's a little bit different, We found that there is a lot of data instances with a
# __jobFunction__ of __['Engineering - Telecom/Technology', 'IT/Software Development']__ but the titles of these instaces are very diverse and we can't just colect them manually like we did in the previous examples, So we had to do it automatically by appending all these titles into one list and then start to improve and enhance this list.
#
# Also change each title into one Unified title : __Software Developer__

# %%
term = "['Engineering - Telecom/Technology', 'IT/Software Development']"
i=0
keywords = []
for jobFunction in jobs_data.jobFunction:
    
    if(jobFunction == term):
        words = jobs_data.title[i].split()  
        jobs_data.title[i]= "Software Developer"
        for word in words:
            if word not in keywords:
                word = word.lower()
                keywords.append(word)
    i+=1

# %% [markdown]
# ##### From here We start working on the list of Software kewords

# %%
keywords_noDupl = list(dict.fromkeys(keywords))
keywords_noDupl
# Out:
# ['full',
#  'stack',
#  'php',
#  'developer',
#  'senior',
#  'back',
#  'end-php',
#  'java',
#  'technical',
#  'lead',
#  'ios',
#  'full-stack',
#  '-',
#  'joomla',
#  'expert',
#  'website',
#  'front-end',
#  'back-end',
#  'odoo',
#  'software',
#  'erp',
#  'implementer',
#  'alexandria',
#  '.net',
#  'tech',
#  'android',
#  'team',
#  'leader',
#  'mid',
#  'web',
#  'associate',
#  'engineer',
#  'wordpress',
#  'junior',
#  '(',
#  'angular',
#  '4+',
#  ')',
#  'tester',
#  '"laravel"',
#  'mobile',
#  'android/ios',
#  'front',
#  'end',
#  'vue.js',
#  '/',
#  'ui/ux',
#  'director',
#  'in',
#  'tunisia',
#  'ge',
#  'mvc',
#  'oracle',
#  'database',
#  'admin',
#  'flutter',
#  'nasr',
#  'city',
#  'it',
#  'help',
#  'desk',
#  'specialist',
#  'minya',
#  'nodejs',
#  'backend',
#  'rpa',
#  'asp.net',
#  'crm',
#  'frontend',
#  '(jquery)',
#  'internship',
#  '"laravel',
#  'project"',
#  'application',
#  'programmer',
#  'monitoring',
#  'agent',
#  'data',
#  'etl',
#  'security',
#  'business',
#  'analyst',
#  'core',
#  'rest',
#  'to',
#  'graphql',
#  'project',
#  'bi/bw',
#  'consultant',
#  'architect',
#  'ionic',
#  'app',
#  'egypt',
#  '(ionic',
#  'flutter)',
#  'node.js',
#  'fullstack',
#  'ms',
#  'dynamics',
#  'react',
#  'native',
#  'epm',
#  'visual',
#  'basic',
#  'sharepoint',
#  'sap',
#  'fi-co',
#  'cisco',
#  'integration',
#  'solution',
#  'ucce',
#  '(freelance)',
#  'ios/android',
#  '(flutter)',
#  'part',
#  'time',
#  'cross-platform',
#  'developer/programmer',
#  'brazil',
#  'serviceability',
#  'blockchain',
#  'mean',
#  '&',
#  'be',
#  'webmethods',
#  'saudi',
#  'arabia',
#  '(php/laravel)',
#  '(react-native)',
#  'filenet/java',
#  'development',
#  '(c#/mvc)',
#  'administrator',
#  'system',
#  'vpn',
#  'network',
#  'owner',
#  'senior.net',
#  'benha',
#  'support',
#  'hcm',
#  'primavera',
#  'p6',
#  'product',
#  'drupal',
#  'principal',
#  'implementation',
#  'indonesia',
#  '|',
#  'scaleup',
#  'ge/a.a',
#  'c++',
#  'qlikview',
#  '(sales',
#  'buzz)',
#  '(.net/sql)',
#  'google',
#  'cloud',
#  'intern',
#  'sr.',
#  'cross',
#  'platform',
#  'infrastructure',
#  'liferay',
#  'bi',
#  'apex',
#  'host',
#  'media',
#  '(information',
#  'technology)',
#  'cabling',
#  'site',
#  'asp',
#  'unity',
#  'apps',
#  '(angular)',
#  'ssis',
#  'sharqia',
#  '(alexandria)',
#  'devops',
#  'cairo',
#  'deployment',
#  'tunis',
#  'hurghada',
#  '(php)',
#  '(part',
#  'time)',
#  '(iot',
#  'department)',
#  '6',
#  'only',
#  'ux/ui',
#  '"microservices"',
#  'angularjs',
#  '(microsoft.net)',
#  '(laravel)',
#  '(c#/asp.net)',
#  'ui',
#  'laravel',
#  'india',
#  'gt',
#  'xamarin',
#  'forms',
#  'manager',
#  '(r&d)',
#  'scientist',
#  'node',
#  'js',
#  'bms',
#  'scrum',
#  'master',
#  'microsoft',
#  'ax',
#  '(techno',
#  'functional',
#  'consultant)',
#  'linux',
#  'react-native',
#  'information',
#  'officer',
#  'stack/',
#  'unified',
#  'communications',
#  '(java',
#  'integration)',
#  'banking',
#  'operator',
#  'server',
#  'php/laravel',
#  'supervisor',
#  'design',
#  'core/angular',
#  '–',
#  'mansoura',
#  'python',
#  'sql',
#  '3d',
#  'vr',
#  'react.js',
#  '.net/angular',
#  '(angular',
#  '2+)',
#  '(node.js/angular)',
#  'rpa/robotics',
#  'success',
#  'factor',
#  'mern',
#  '(windows)',
#  'bw',
#  'mm',
#  'head',
#  'of',
#  'delivery',
#  '(leading',
#  'branch)',
#  'abap',
#  '(linux)',
#  'cognos',
#  'magento',
#  '(.net)',
#  'middle',
#  'ware',
#  'hybris',
#  'stack.',
#  'net',
#  'vuejs',
#  '(laravel',
#  'yii',
#  'codeigniter)',
#  'dba',
#  'ibm',
#  'datapower',
#  'gateway',
#  'level',
#  'oracle/sql',
#  'db',
#  'cnc',
#  'milling',
#  'cto',
#  '(chief',
#  'technology',
#  'officer)',
#  'golang',
#  'odoo/',
#  'next',
#  'reactjs',
#  'freelance/part',
#  'ruby',
#  'on',
#  'rails',
#  'storage',
#  'up',
#  'pre-sales',
#  '"data',
#  'center',
#  'surveillance"',
#  'hybrid',
#  'applications',
#  '(gerber)',
#  '(java)',
#  'turkey',
#  'senior\\team',
#  ',',
#  'ionic)',
#  'computer',
#  'science',
#  'engineering',
#  'fresh',
#  'graduates',
#  'e-commerce',
#  'deep',
#  'learning',
#  'researcher',
#  'protection',
#  'and',
#  'control',
#  'qilk',
#  'iib',
#  'bpm/odm',
#  'hyperion',
#  'planning',
#  'remotely',
#  '7',
#  'embedded',
#  'codeigniter/laravel',
#  '(catalogue)',
#  'partner',
#  'credit',
#  'card',
#  'projects',
#  'c',
#  '#',
#  '-entity',
#  'framework',
#  'developer/web',
#  'designer',
#  'kickstart',
#  '[marketing]',
#  'developer/',
#  '(laravel,',
#  'vue)',
#  'dakahlia',
#  'graduate',
#  'unpaid',
#  'subject',
#  'code',
#  '[sui01]',
#  'datacap',
#  '[sbe01]',
#  'automotive',
#  'bootcamp',
#  'wave',
#  '[stl01]',
#  '[be01]',
#  '(php',
#  'angular)',
#  '(wordpress/woocommerce)',
#  'riyadh',
#  'engineer/cloud',
#  'or',
#  'alex',
#  'avaya',
#  'voice',
#  'ksa',
#  '[it]',
#  'twimbit',
#  'resident',
#  'iti',
#  'riseup',
#  'developer-ge/a.a',
#  '(react/react-native)',
#  '(hybrid',
#  'applications)',
#  '(outsource)',
#  'jeddah',
#  '(node.js)',
#  'services',
#  '(mid-level)',
#  'javascript',
#  '(react',
#  'native)',
#  'l2',
#  'hardware',
#  'java-ee',
#  'freelance',
#  '(erp',
#  'next)',
#  'document',
#  'controller',
#  'for',
#  'contact',
#  'technologies',
#  '(ios/android)',
#  'game',
#  'salesforce.com',
#  'tech.',
#  'active',
#  'directory',
#  'sd/tm',
#  'vmware',
#  'windows',
#  'modeler',
#  'move2root',
#  'with',
#  '(nodejs)',
#  'wpf',
#  'testing',
#  'end-web',
#  'ember.js',
#  'web/mobile',
#  'developer/lead',
#  'mid-senior',
#  'monufya',
#  'coordinator',
#  '(android',
#  'lead)',
#  'opentext',
#  'ecm',
#  '(implementer)',
#  'developer,',
#  'factors/hcm',
#  'dubai',
#  'sw',
#  '(asp.net)',
#  'professional',
#  'django',
#  'symfony',
#  'scm',
#  'automation',
#  'hr',
#  'writer',
#  'agile',
#  '(owner',
#  'surveillance',
#  'access',
#  'system)']

# %% [markdown]
# 1. Remove Spaces, punctuations, numbers and single charcter using __regular expressions__
# 2. Manullay inspect and collect some generic words inside the list to be removed
# 3. Add 2 parts words that are removd with generic words

# %%
import re
i=0
for word in keywords_noDupl:
    # Removing multiple spaces
    word = re.sub(r'\s+', ' ', word)
    # Remove punctuations and numbers
    word = re.sub('[^a-zA-Z]', ' ', word)
    # Single character removal
    word = re.sub(r"\s+[a-zA-Z]\s+", ' ', word)

    keywords_noDupl[i]=word
    i+=1
    
GeneralWords = ['full','alexandria','owner', 'surveillance','access', 'system','leader','stack','senior','back','lead','-','expert','team', 'leader', 'mid', 'associate', 'engineer', 'end',  'front', 'nasr', 'city', 'help', 'desk', 'specialist','minya', 'internship','project',  'monitoring','agent', 'security',  'senior\\team','#','freelance/part','consultant','architect','egypt', 'solution','4+','brazil', 'saudi', 'arabia', 'owner','kickstart','[marketing]', 'designer','riyadh','alex','ksa','riseup', 'contact', 'salesforce.com', 'dubai', 'business', 'analyst', 'core', 'rest','to', 'benha', 'product', 'principal', 'indonesia', 'implementation', '(sales', 'buzz)', 'intern', 'cross', 'remotely', 'platform','infrastructure','cairo','liferay', 'turkey','-entity', 'professional', 'bi','host','sharqia','tunis','(part', 'department)','only','india', 'time)','forms','officer', 'success','bw','fresh','graduates', 'monufya','coordinator','e-commerce', 'dakahlia','graduate','unpaid','(outsource)', 'hr','writer','jeddah','services','subject','mm', 'middle', 'next','on','up','deep','learning','pre-sales','ware','head','level','of','delivery','(leading','branch)','factor','stack/', 'supervisor', 'design','unified','banking', 'mansoura','communications', 'manager', 'functional', 'consultant)', '(r&d)', 'scientist','hurghada','(alexandria)','media','(information']
i=0

 

for word in keywords_noDupl:
    if word in GeneralWords:
        keywords_noDupl.remove(word)
    i+=1
#add 2 parts words technical lead, tech lead, back end, front end,react native, computer engineer, c#,middle ware, ruby on rails

keywords_noDupl.append('technical lead')
keywords_noDupl.append('back end')
keywords_noDupl.append('front end')
keywords_noDupl.append('react native')
keywords_noDupl.append('computer engineer')
keywords_noDupl.append('c#')
keywords_noDupl.append('middle ware')
keywords_noDupl.append('ruby on rails')


#in order to include stopwords in our code we had to use nltk.download() which will open a window for us,
#from which we can use stopwords to download 

# nltk.download()
import nltk
from nltk.corpus import stopwords

#By trial and error, we found that the process of eliminating the stop words from our data
#needs to be done 3 times at least to get rid of all stop words

for word in keywords_noDupl:
    if word in (stopwords.words('english')):
        keywords_noDupl.remove(word)
        
#remove remaining spaces
k=0
for word in keywords_noDupl:
    if word == ' ':
        del keywords_noDupl[k]
    k+=1

Software_Keywords = keywords_noDupl

# %% [markdown]
# # 2. Machine learning Model

# %% [markdown]
# We start be preparing the data into our machine learning model.
#
# We will be using Deep learning model this time. Our apprach for preparing the dataset is, Binary Encoding to the targets of the dataset (JobFunctions), and vectorizing the features (title) as we did with naive bayes
#
# __in order__ to bunary Encode the targets we first need to change it;s form from string to itegeres

# %%
labels = jobs_data.jobFunction.astype("category").cat.codes
train_data = jobs_data['title']

# %% [markdown]
# We are going to save a Map between the original text of all job functions and it's corrosponding Encoded integer

# %%
Map = dict( zip( jobs_data['jobFunction'].astype("category").cat.codes, jobs_data['jobFunction'] ) )
Map
# Out:
# {313: "['Engineering - Telecom/Technology', 'IT/Software Development']",
#  435: "['Installation/Maintenance/Repair', 'IT/Software Development', 'Engineering - Telecom/Technology']",
#  127: "['Creative/Design/Art', 'IT/Software Development']",
#  372: "['IT/Software Development', 'Engineering - Telecom/Technology', 'Customer Service/Support']",
#  260: "['Engineering - Mechanical/Electrical']",
#  803: "['Sales/Retail']",
#  180: "['Education/Teaching', 'Administration', 'Operations/Management']",
#  787: "['Sales/Retail', 'Marketing/PR/Advertising', 'Media/Journalism/Publishing']",
#  23: "['Accounting/Finance']",
#  759: "['Sales/Retail', 'Creative/Design/Art']",
#  205: "['Education/Teaching']",
#  557: "['Media/Journalism/Publishing', 'Marketing/PR/Advertising']",
#  536: "['Marketing/PR/Advertising', 'Sales/Retail']",
#  403: "['IT/Software Development', 'Sales/Retail', 'Engineering - Telecom/Technology']",
#  132: "['Creative/Design/Art', 'Media/Journalism/Publishing']",
#  540: "['Marketing/PR/Advertising']",
#  404: "['IT/Software Development', 'Sales/Retail']",
#  62: "['Administration']",
#  53: "['Administration', 'Operations/Management', 'Sales/Retail']",
#  814: "['Training/Instructor', 'Education/Teaching']",
#  753: "['R&D/Science']",
#  465: "['Logistics/Supply Chain', 'Purchasing/Procurement']",
#  688: "['Project/Program Management', 'IT/Software Development']",
#  682: "['Project/Program Management', 'Engineering - Telecom/Technology', 'IT/Software Development']",
#  320: "['Engineering - Telecom/Technology', 'Project/Program Management', 'IT/Software Development']",
#  120: "['Creative/Design/Art', 'Engineering - Construction/Civil/Architecture']",
#  342: "['Human Resources']",
#  310: "['Engineering - Telecom/Technology', 'IT/Software Development', 'Quality']",
#  255: "['Engineering - Mechanical/Electrical', 'Project/Program Management']",
#  344: "['IT/Software Development', 'Accounting/Finance']",
#  381: "['IT/Software Development', 'Engineering - Telecom/Technology', 'Quality']",
#  826: "['Writing/Editorial', 'Marketing/PR/Advertising', 'Media/Journalism/Publishing']",
#  177: "['Customer Service/Support']",
#  523: "['Marketing/PR/Advertising', 'Media/Journalism/Publishing']",
#  546: "['Media/Journalism/Publishing', 'Creative/Design/Art']",
#  833: "['Writing/Editorial']",
#  764: "['Sales/Retail', 'Customer Service/Support']",
#  96: "['Business Development', 'IT/Software Development']",
#  776: "['Sales/Retail', 'IT/Software Development', 'Engineering - Mechanical/Electrical']",
#  834: "['nan']",
#  136: "['Creative/Design/Art']",
#  670: "['Project/Program Management', 'Analyst/Research', 'IT/Software Development']",
#  68: "['Analyst/Research', 'IT/Software Development', 'Creative/Design/Art']",
#  389: "['IT/Software Development', 'Installation/Maintenance/Repair']",
#  116: "['Business Development']",
#  766: "['Sales/Retail', 'Engineering - Mechanical/Electrical', 'Engineering - Construction/Civil/Architecture']",
#  231: "['Engineering - Construction/Civil/Architecture']",
#  449: "['Legal']",
#  201: "['Education/Teaching', 'Sports and Leisure']",
#  75: "['Analyst/Research', 'Operations/Management', 'IT/Software Development']",
#  80: "['Analyst/Research']",
#  412: "['Installation/Maintenance/Repair', 'Administration']",
#  531: "['Marketing/PR/Advertising', 'Sales/Retail', 'Business Development']",
#  297: "['Engineering - Telecom/Technology', 'Engineering - Mechanical/Electrical', 'Installation/Maintenance/Repair']",
#  429: "['Installation/Maintenance/Repair', 'Engineering - Telecom/Technology', 'IT/Software Development']",
#  573: "['Medical/Healthcare', 'Marketing/PR/Advertising', 'Business Development']",
#  267: "['Engineering - Other', 'Creative/Design/Art']",
#  467: "['Logistics/Supply Chain']",
#  230: "['Engineering - Construction/Civil/Architecture', 'Sales/Retail']",
#  259: "['Engineering - Mechanical/Electrical', 'Sales/Retail']",
#  624: "['Operations/Management', 'Logistics/Supply Chain', 'Engineering - Other']",
#  208: "['Engineering - Construction/Civil/Architecture', 'Business Development']",
#  14: "['Accounting/Finance', 'IT/Software Development']",
#  55: "['Administration', 'Project/Program Management', 'Engineering - Construction/Civil/Architecture']",
#  723: "['Quality', 'IT/Software Development', 'Engineering - Telecom/Technology']",
#  506: "['Marketing/PR/Advertising', 'Creative/Design/Art']",
#  438: "['Installation/Maintenance/Repair', 'IT/Software Development']",
#  509: "['Marketing/PR/Advertising', 'Customer Service/Support', 'Sales/Retail']",
#  758: "['Sales/Retail', 'Business Development']",
#  585: "['Medical/Healthcare']",
#  501: "['Marketing/PR/Advertising', 'Business Development', 'Sales/Retail']",
#  328: "['Engineering - Telecom/Technology']",
#  0: "['Accounting/Finance', 'Administration', 'Operations/Management']",
#  784: "['Sales/Retail', 'Marketing/PR/Advertising', 'Business Development']",
#  631: "['Operations/Management', 'Marketing/PR/Advertising', 'Media/Journalism/Publishing']",
#  541: "['Media/Journalism/Publishing', 'Administration', 'Marketing/PR/Advertising']",
#  358: "['IT/Software Development', 'Creative/Design/Art']",
#  450: "['Logistics/Supply Chain', 'Accounting/Finance']",
#  796: "['Sales/Retail', 'Operations/Management']",
#  366: "['IT/Software Development', 'Engineering - Mechanical/Electrical', 'Engineering - Telecom/Technology']",
#  451: "['Logistics/Supply Chain', 'Administration', 'Customer Service/Support']",
#  174: "['Customer Service/Support', 'Sales/Retail']",
#  724: "['Quality', 'IT/Software Development']",
#  785: "['Sales/Retail', 'Marketing/PR/Advertising', 'Customer Service/Support']",
#  562: "['Media/Journalism/Publishing', 'Writing/Editorial', 'Marketing/PR/Advertising']",
#  538: "['Marketing/PR/Advertising', 'Writing/Editorial', 'Media/Journalism/Publishing']",
#  253: "['Engineering - Mechanical/Electrical', 'Operations/Management']",
#  215: "['Engineering - Construction/Civil/Architecture', 'Engineering - Other']",
#  737: "['Quality', 'R&D/Science']",
#  769: "['Sales/Retail', 'Engineering - Mechanical/Electrical']",
#  666: "['Pharmaceutical', 'Sales/Retail']",
#  722: "['Quality', 'Engineering - Telecom/Technology', 'IT/Software Development']",
#  493: "['Marketing/PR/Advertising', 'Administration', 'Operations/Management']",
#  189: "['Education/Teaching', 'Engineering - Telecom/Technology', 'IT/Software Development']",
#  303: "['Engineering - Telecom/Technology', 'IT/Software Development', 'Creative/Design/Art']",
#  700: "['Purchasing/Procurement', 'Engineering - Mechanical/Electrical']",
#  695: "['Project/Program Management']",
#  565: "['Media/Journalism/Publishing']",
#  35: "['Administration', 'Human Resources']",
#  762: "['Sales/Retail', 'Customer Service/Support', 'IT/Software Development']",
#  309: "['Engineering - Telecom/Technology', 'IT/Software Development', 'Project/Program Management']",
#  795: "['Sales/Retail', 'Operations/Management', 'Business Development']",
#  16: "['Accounting/Finance', 'Operations/Management']",
#  115: "['Business Development', 'Sales/Retail']",
#  110: "['Business Development', 'Sales/Retail', 'Customer Service/Support']",
#  150: "['Customer Service/Support', 'IT/Software Development']",
#  137: "['Customer Service/Support', 'Administration']",
#  256: "['Engineering - Mechanical/Electrical', 'Purchasing/Procurement']",
#  213: "['Engineering - Construction/Civil/Architecture', 'Engineering - Mechanical/Electrical']",
#  778: "['Sales/Retail', 'IT/Software Development']",
#  383: "['IT/Software Development', 'Engineering - Telecom/Technology', 'Sales/Retail']",
#  324: "['Engineering - Telecom/Technology', 'Sales/Retail', 'IT/Software Development']",
#  376: "['IT/Software Development', 'Engineering - Telecom/Technology', 'Installation/Maintenance/Repair']",
#  476: "['Manufacturing/Production', 'Engineering - Other']",
#  287: "['Engineering - Telecom/Technology', 'Creative/Design/Art', 'IT/Software Development']",
#  827: "['Writing/Editorial', 'Marketing/PR/Advertising']",
#  413: "['Installation/Maintenance/Repair', 'Business Development', 'IT/Software Development']",
#  388: "['IT/Software Development', 'Installation/Maintenance/Repair', 'Engineering - Telecom/Technology']",
#  773: "['Sales/Retail', 'Engineering - Telecom/Technology']",
#  30: "['Administration', 'Customer Service/Support']",
#  118: "['Creative/Design/Art', 'Education/Teaching']",
#  298: "['Engineering - Telecom/Technology', 'Engineering - Mechanical/Electrical']",
#  234: "['Engineering - Mechanical/Electrical', 'Creative/Design/Art']",
#  284: "['Engineering - Other']",
#  37: "['Administration', 'IT/Software Development']",
#  100: "['Business Development', 'Marketing/PR/Advertising', 'Sales/Retail']",
#  45: "['Administration', 'Marketing/PR/Advertising']",
#  155: "['Customer Service/Support', 'Marketing/PR/Advertising']",
#  264: "['Engineering - Oil & Gas/Energy', 'Sales/Retail']",
#  129: "['Creative/Design/Art', 'Marketing/PR/Advertising', 'Media/Journalism/Publishing']",
#  707: "['Purchasing/Procurement', 'Logistics/Supply Chain']",
#  125: "['Creative/Design/Art', 'IT/Software Development', 'Engineering - Telecom/Technology']",
#  406: "['IT/Software Development', 'Strategy/Consulting']",
#  40: "['Administration', 'Installation/Maintenance/Repair']",
#  550: "['Media/Journalism/Publishing', 'Marketing/PR/Advertising', 'Customer Service/Support']",
#  755: "['Sales/Retail', 'Business Development', 'Customer Service/Support']",
#  747: "['R&D/Science', 'Medical/Healthcare', 'Pharmaceutical']",
#  484: "['Manufacturing/Production', 'Operations/Management', 'Logistics/Supply Chain']",
#  315: "['Engineering - Telecom/Technology', 'Installation/Maintenance/Repair', 'IT/Software Development']",
#  133: "['Creative/Design/Art', 'Operations/Management']",
#  54: "['Administration', 'Operations/Management']",
#  678: "['Project/Program Management', 'Engineering - Mechanical/Electrical', 'Engineering - Other']",
#  398: "['IT/Software Development', 'Project/Program Management']",
#  555: "['Media/Journalism/Publishing', 'Marketing/PR/Advertising', 'Sales/Retail']",
#  800: "['Sales/Retail', 'R&D/Science', 'Medical/Healthcare']",
#  410: "['IT/Software Development']",
#  709: "['Purchasing/Procurement']",
#  321: "['Engineering - Telecom/Technology', 'Quality', 'IT/Software Development']",
#  60: "['Administration', 'Sales/Retail']",
#  643: "['Operations/Management', 'Purchasing/Procurement']",
#  679: "['Project/Program Management', 'Engineering - Mechanical/Electrical']",
#  19: "['Accounting/Finance', 'Quality', 'IT/Software Development']",
#  528: "['Marketing/PR/Advertising', 'Operations/Management']",
#  475: "['Manufacturing/Production', 'Engineering - Other', 'Sales/Retail']",
#  64: "['Analyst/Research', 'Engineering - Construction/Civil/Architecture', 'Project/Program Management']",
#  131: "['Creative/Design/Art', 'Media/Journalism/Publishing', 'Marketing/PR/Advertising']",
#  349: "['IT/Software Development', 'Analyst/Research', 'Engineering - Telecom/Technology']",
#  817: "['Training/Instructor', 'Marketing/PR/Advertising']",
#  146: "['Customer Service/Support', 'IT/Software Development', 'Engineering - Telecom/Technology']",
#  657: "['Pharmaceutical', 'Operations/Management']",
#  143: "['Customer Service/Support', 'Engineering - Telecom/Technology', 'IT/Software Development']",
#  399: "['IT/Software Development', 'Quality', 'Engineering - Telecom/Technology']",
#  196: "['Education/Teaching', 'Operations/Management']",
#  351: "['IT/Software Development', 'Analyst/Research', 'Sales/Retail']",
#  251: "['Engineering - Mechanical/Electrical', 'Manufacturing/Production']",
#  210: "['Engineering - Construction/Civil/Architecture', 'Creative/Design/Art']",
#  283: "['Engineering - Other', 'Sales/Retail']",
#  134: "['Creative/Design/Art', 'Sales/Retail', 'Marketing/PR/Advertising']",
#  371: "['IT/Software Development', 'Engineering - Telecom/Technology', 'Creative/Design/Art']",
#  633: "['Operations/Management', 'Marketing/PR/Advertising', 'Sales/Retail']",
#  99: "['Business Development', 'Marketing/PR/Advertising', 'Operations/Management']",
#  788: "['Sales/Retail', 'Marketing/PR/Advertising']",
#  149: "['Customer Service/Support', 'IT/Software Development', 'Sales/Retail']",
#  123: "['Creative/Design/Art', 'Engineering - Telecom/Technology', 'IT/Software Development']",
#  354: "['IT/Software Development', 'Business Development', 'Customer Service/Support']",
#  252: "['Engineering - Mechanical/Electrical', 'Operations/Management', 'Manufacturing/Production']",
#  698: "['Purchasing/Procurement', 'Administration']",
#  157: "['Customer Service/Support', 'Medical/Healthcare', 'Administration']",
#  821: "['Training/Instructor']",
#  112: "['Business Development', 'Sales/Retail', 'Marketing/PR/Advertising']",
#  425: "['Installation/Maintenance/Repair', 'Engineering - Mechanical/Electrical']",
#  229: "['Engineering - Construction/Civil/Architecture', 'Sales/Retail', 'Project/Program Management']",
#  122: "['Creative/Design/Art', 'Engineering - Mechanical/Electrical']",
#  823: "['Writing/Editorial', 'Education/Teaching']",
#  715: "['Quality', 'Engineering - Construction/Civil/Architecture']",
#  352: "['IT/Software Development', 'Analyst/Research']",
#  347: "['IT/Software Development', 'Analyst/Research', 'Business Development']",
#  66: "['Analyst/Research', 'Engineering - Telecom/Technology', 'IT/Software Development']",
#  745: "['R&D/Science', 'Engineering - Telecom/Technology', 'IT/Software Development']",
#  685: "['Project/Program Management', 'IT/Software Development', 'Engineering - Telecom/Technology']",
#  712: "['Quality', 'Banking']",
#  741: "['R&D/Science', 'Education/Teaching']",
#  307: "['Engineering - Telecom/Technology', 'IT/Software Development', 'Installation/Maintenance/Repair']",
#  339: "['Human Resources', 'IT/Software Development']",
#  396: "['IT/Software Development', 'Project/Program Management', 'Engineering - Telecom/Technology']",
#  771: "['Sales/Retail', 'Engineering - Telecom/Technology', 'IT/Software Development']",
#  200: "['Education/Teaching', 'R&D/Science']",
#  357: "['IT/Software Development', 'Creative/Design/Art', 'Engineering - Telecom/Technology']",
#  130: "['Creative/Design/Art', 'Marketing/PR/Advertising']",
#  380: "['IT/Software Development', 'Engineering - Telecom/Technology', 'Project/Program Management']",
#  108: "['Business Development', 'Project/Program Management', 'Sales/Retail']",
#  794: "['Sales/Retail', 'Medical/Healthcare']",
#  57: "['Administration', 'Purchasing/Procurement']",
#  185: "['Education/Teaching', 'Creative/Design/Art']",
#  360: "['IT/Software Development', 'Customer Service/Support', 'Engineering - Telecom/Technology']",
#  522: "['Marketing/PR/Advertising', 'Media/Journalism/Publishing', 'Writing/Editorial']",
#  549: "['Media/Journalism/Publishing', 'Marketing/PR/Advertising', 'Creative/Design/Art']",
#  292: "['Engineering - Telecom/Technology', 'Customer Service/Support']",
#  828: "['Writing/Editorial', 'Media/Journalism/Publishing', 'Marketing/PR/Advertising']",
#  203: "['Education/Teaching', 'Training/Instructor']",
#  263: "['Engineering - Oil & Gas/Energy', 'Engineering - Other', 'Sales/Retail']",
#  246: "['Engineering - Mechanical/Electrical', 'Installation/Maintenance/Repair']",
#  258: "['Engineering - Mechanical/Electrical', 'Sales/Retail', 'Engineering - Construction/Civil/Architecture']",
#  701: "['Purchasing/Procurement', 'Engineering - Other', 'Logistics/Supply Chain']",
#  138: "['Customer Service/Support', 'Engineering - Construction/Civil/Architecture']",
#  415: "['Installation/Maintenance/Repair', 'Customer Service/Support', 'IT/Software Development']",
#  751: "['R&D/Science', 'Quality']",
#  532: "['Marketing/PR/Advertising', 'Sales/Retail', 'Customer Service/Support']",
#  67: "['Analyst/Research', 'Engineering - Telecom/Technology']",
#  88: "['Business Development', 'Customer Service/Support']",
#  503: "['Marketing/PR/Advertising', 'Creative/Design/Art', 'Media/Journalism/Publishing']",
#  646: "['Operations/Management', 'Sales/Retail']",
#  301: "['Engineering - Telecom/Technology', 'IT/Software Development', 'Analyst/Research']",
#  456: "['Logistics/Supply Chain', 'Engineering - Construction/Civil/Architecture', 'Engineering - Mechanical/Electrical']",
#  659: "['Pharmaceutical', 'Project/Program Management']",
#  414: "['Installation/Maintenance/Repair', 'Customer Service/Support', 'Engineering - Mechanical/Electrical']",
#  363: "['IT/Software Development', 'Customer Service/Support']",
#  69: "['Analyst/Research', 'IT/Software Development', 'Quality']",
#  644: "['Operations/Management', 'Sales/Retail', 'Business Development']",
#  334: "['Hospitality/Hotels/Food Services']",
#  781: "['Sales/Retail', 'Logistics/Supply Chain']",
#  432: "['Installation/Maintenance/Repair', 'Engineering - Telecom/Technology']",
#  15: "['Accounting/Finance', 'Logistics/Supply Chain']",
#  71: "['Analyst/Research', 'Marketing/PR/Advertising', 'Media/Journalism/Publishing']",
#  50: "['Administration', 'Operations/Management', 'Customer Service/Support']",
#  424: "['Installation/Maintenance/Repair', 'Engineering - Mechanical/Electrical', 'Sales/Retail']",
#  401: "['IT/Software Development', 'Sales/Retail', 'Business Development']",
#  378: "['IT/Software Development', 'Engineering - Telecom/Technology', 'Marketing/PR/Advertising']",
#  1: "['Accounting/Finance', 'Administration']",
#  316: "['Engineering - Telecom/Technology', 'Installation/Maintenance/Repair', 'Project/Program Management']",
#  420: "['Installation/Maintenance/Repair', 'Engineering - Mechanical/Electrical', 'Engineering - Telecom/Technology']",
#  518: "['Marketing/PR/Advertising', 'Media/Journalism/Publishing', 'Creative/Design/Art']",
#  97: "['Business Development', 'Installation/Maintenance/Repair', 'IT/Software Development']",
#  502: "['Marketing/PR/Advertising', 'Business Development']",
#  719: "['Quality', 'Engineering - Other', 'Manufacturing/Production']",
#  290: "['Engineering - Telecom/Technology', 'Customer Service/Support', 'IT/Software Development']",
#  91: "['Business Development', 'IT/Software Development', 'Analyst/Research']",
#  427: "['Installation/Maintenance/Repair', 'Engineering - Other']",
#  225: "['Engineering - Construction/Civil/Architecture', 'Purchasing/Procurement']",
#  408: "['IT/Software Development', 'Writing/Editorial', 'Project/Program Management']",
#  556: "['Media/Journalism/Publishing', 'Marketing/PR/Advertising', 'Writing/Editorial']",
#  350: "['IT/Software Development', 'Analyst/Research', 'Project/Program Management']",
#  192: "['Education/Teaching', 'IT/Software Development']",
#  583: "['Medical/Healthcare', 'Sales/Retail']",
#  373: "['IT/Software Development', 'Engineering - Telecom/Technology', 'Education/Teaching']",
#  151: "['Customer Service/Support', 'Installation/Maintenance/Repair', 'IT/Software Development']",
#  544: "['Media/Journalism/Publishing', 'Business Development', 'Marketing/PR/Advertising']",
#  195: "['Education/Teaching', 'Operations/Management', 'Training/Instructor']",
#  368: "['IT/Software Development', 'Engineering - Other']",
#  400: "['IT/Software Development', 'Quality']",
#  224: "['Engineering - Construction/Civil/Architecture', 'Project/Program Management']",
#  308: "['Engineering - Telecom/Technology', 'IT/Software Development', 'Operations/Management']",
#  274: "['Engineering - Other', 'Manufacturing/Production']",
#  243: "['Engineering - Mechanical/Electrical', 'Installation/Maintenance/Repair', 'Engineering - Telecom/Technology']",
#  584: "['Medical/Healthcare', 'Writing/Editorial', 'Media/Journalism/Publishing']",
#  21: "['Accounting/Finance', 'Strategy/Consulting', 'IT/Software Development']",
#  377: "['IT/Software Development', 'Engineering - Telecom/Technology', 'Manufacturing/Production']",
#  447: "['Installation/Maintenance/Repair']",
#  111: "['Business Development', 'Sales/Retail', 'IT/Software Development']",
#  33: "['Administration', 'Engineering - Construction/Civil/Architecture']",
#  237: "['Engineering - Mechanical/Electrical', 'Engineering - Oil & Gas/Energy', 'Sales/Retail']",
#  526: "['Marketing/PR/Advertising', 'Operations/Management', 'IT/Software Development']",
#  204: "['Education/Teaching', 'Writing/Editorial']",
#  599: "['Operations/Management', 'Education/Teaching']",
#  515: "['Marketing/PR/Advertising', 'Manufacturing/Production']",
#  660: "['Pharmaceutical', 'Quality', 'Medical/Healthcare']",
#  82: "['Banking', 'Quality']",
#  610: "['Operations/Management', 'Engineering - Telecom/Technology', 'Project/Program Management']",
#  326: "['Engineering - Telecom/Technology', 'Sales/Retail']",
#  65: "['Analyst/Research', 'Engineering - Other']",
#  479: "['Manufacturing/Production', 'IT/Software Development', 'Engineering - Telecom/Technology']",
#  76: "['Analyst/Research', 'Project/Program Management', 'IT/Software Development']",
#  739: "['Quality']",
#  305: "['Engineering - Telecom/Technology', 'IT/Software Development', 'Education/Teaching']",
#  663: "['Pharmaceutical', 'R&D/Science', 'Project/Program Management']",
#  721: "['Quality', 'Engineering - Other']",
#  121: "['Creative/Design/Art', 'Engineering - Mechanical/Electrical', 'Engineering - Telecom/Technology']",
#  829: "['Writing/Editorial', 'Media/Journalism/Publishing']",
#  600: "['Operations/Management', 'Engineering - Construction/Civil/Architecture', 'Creative/Design/Art']",
#  7: "['Accounting/Finance', 'Customer Service/Support']",
#  428: "['Installation/Maintenance/Repair', 'Engineering - Telecom/Technology', 'Engineering - Mechanical/Electrical']",
#  582: "['Medical/Healthcare', 'R&D/Science']",
#  775: "['Sales/Retail', 'IT/Software Development', 'Customer Service/Support']",
#  770: "['Sales/Retail', 'Engineering - Other']",
#  564: "['Media/Journalism/Publishing', 'Writing/Editorial']",
#  29: "['Administration', 'Customer Service/Support', 'Sales/Retail']",
#  13: "['Accounting/Finance', 'IT/Software Development', 'Strategy/Consulting']",
#  752: "['R&D/Science', 'Sales/Retail', 'Engineering - Other']",
#  165: "['Customer Service/Support', 'Sales/Retail', 'Business Development']",
#  170: "['Customer Service/Support', 'Sales/Retail', 'Marketing/PR/Advertising']",
#  223: "['Engineering - Construction/Civil/Architecture', 'Operations/Management']",
#  98: "['Business Development', 'Marketing/PR/Advertising', 'Customer Service/Support']",
#  61: "['Administration', 'Training/Instructor']",
#  445: "['Installation/Maintenance/Repair', 'Operations/Management', 'Engineering - Telecom/Technology']",
#  508: "['Marketing/PR/Advertising', 'Customer Service/Support', 'Media/Journalism/Publishing']",
#  547: "['Media/Journalism/Publishing', 'Marketing/PR/Advertising', 'Analyst/Research']",
#  56: "['Administration', 'Project/Program Management']",
#  777: "['Sales/Retail', 'IT/Software Development', 'Engineering - Telecom/Technology']",
#  95: "['Business Development', 'IT/Software Development', 'Sales/Retail']",
#  676: "['Project/Program Management', 'Engineering - Construction/Civil/Architecture', 'Analyst/Research']",
#  240: "['Engineering - Mechanical/Electrical', 'Engineering - Telecom/Technology']",
#  790: "['Sales/Retail', 'Media/Journalism/Publishing', 'Marketing/PR/Advertising']",
#  634: "['Operations/Management', 'Marketing/PR/Advertising']",
#  72: "['Analyst/Research', 'Marketing/PR/Advertising', 'Sales/Retail']",
#  102: "['Business Development', 'Media/Journalism/Publishing', 'Marketing/PR/Advertising']",
#  626: "['Operations/Management', 'Logistics/Supply Chain']",
#  160: "['Customer Service/Support', 'Operations/Management', 'Administration']",
#  680: "['Project/Program Management', 'Engineering - Other', 'Engineering - Mechanical/Electrical']",
#  219: "['Engineering - Construction/Civil/Architecture', 'Installation/Maintenance/Repair']",
#  594: "['Operations/Management', 'Customer Service/Support', 'Project/Program Management']",
#  816: "['Training/Instructor', 'IT/Software Development']",
#  548: "['Media/Journalism/Publishing', 'Marketing/PR/Advertising', 'Business Development']",
#  499: "['Marketing/PR/Advertising', 'Business Development', 'Engineering - Other']",
#  181: "['Education/Teaching', 'Administration']",
#  473: "['Manufacturing/Production', 'Engineering - Mechanical/Electrical']",
#  296: "['Engineering - Telecom/Technology', 'Engineering - Mechanical/Electrical', 'IT/Software Development']",
#  126: "['Creative/Design/Art', 'IT/Software Development', 'Training/Instructor']",
#  391: "['IT/Software Development', 'Marketing/PR/Advertising']",
#  162: "['Customer Service/Support', 'Operations/Management']",
#  521: "['Marketing/PR/Advertising', 'Media/Journalism/Publishing', 'Sales/Retail']",
#  103: "['Business Development', 'Medical/Healthcare', 'Marketing/PR/Advertising']",
#  677: "['Project/Program Management', 'Engineering - Construction/Civil/Architecture']",
#  84: "['Business Development', 'Analyst/Research', 'IT/Software Development']",
#  510: "['Marketing/PR/Advertising', 'Customer Service/Support']",
#  614: "['Operations/Management', 'Human Resources']",
#  178: "['Education/Teaching', 'Accounting/Finance', 'Training/Instructor']",
#  279: "['Engineering - Other', 'R&D/Science', 'Medical/Healthcare']",
#  106: "['Business Development', 'Operations/Management', 'Sales/Retail']",
#  689: "['Project/Program Management', 'Installation/Maintenance/Repair', 'Engineering - Telecom/Technology']",
#  481: "['Manufacturing/Production', 'Logistics/Supply Chain']",
#  743: "['R&D/Science', 'Engineering - Other', 'Quality']",
#  369: "['IT/Software Development', 'Engineering - Telecom/Technology', 'Accounting/Finance']",
#  353: "['IT/Software Development', 'Banking', 'Analyst/Research']",
#  444: "['Installation/Maintenance/Repair', 'Operations/Management', 'Engineering - Other']",
#  2: "['Accounting/Finance', 'Analyst/Research']",
#  52: "['Administration', 'Operations/Management', 'Marketing/PR/Advertising']",
#  746: "['R&D/Science', 'Installation/Maintenance/Repair', 'Medical/Healthcare']",
#  119: "['Creative/Design/Art', 'Engineering - Construction/Civil/Architecture', 'Engineering - Mechanical/Electrical']",
#  374: "['IT/Software Development', 'Engineering - Telecom/Technology', 'Engineering - Mechanical/Electrical']",
#  673: "['Project/Program Management', 'Creative/Design/Art', 'Engineering - Construction/Civil/Architecture']",
#  813: "['Training/Instructor', 'Education/Teaching', 'IT/Software Development']",
#  176: "['Customer Service/Support', 'Tourism/Travel']",
#  24: "['Administration', 'Accounting/Finance']",
#  638: "['Operations/Management', 'Pharmaceutical']",
#  520: "['Marketing/PR/Advertising', 'Media/Journalism/Publishing', 'Operations/Management']",
#  306: "['Engineering - Telecom/Technology', 'IT/Software Development', 'Engineering - Mechanical/Electrical']",
#  713: "['Quality', 'Education/Teaching']",
#  480: "['Manufacturing/Production', 'Logistics/Supply Chain', 'Engineering - Other']",
#  285: "['Engineering - Telecom/Technology', 'Analyst/Research', 'IT/Software Development']",
#  5: "['Accounting/Finance', 'C-Level Executive/GM/Director']",
#  806: "['Strategy/Consulting', 'IT/Software Development', 'Engineering - Telecom/Technology']",
#  194: "['Education/Teaching', 'Medical/Healthcare', 'Training/Instructor']",
#  375: "['IT/Software Development', 'Engineering - Telecom/Technology', 'Engineering - Other']",
#  183: "['Education/Teaching', 'Business Development', 'Administration']",
#  725: "['Quality', 'Manufacturing/Production', 'Engineering - Mechanical/Electrical']",
#  345: "['IT/Software Development', 'Administration']",
#  690: "['Project/Program Management', 'Installation/Maintenance/Repair', 'IT/Software Development']",
#  452: "['Logistics/Supply Chain', 'Administration']",
#  731: "['Quality', 'Operations/Management']",
#  774: "['Sales/Retail', 'IT/Software Development', 'Business Development']",
#  394: "['IT/Software Development', 'Project/Program Management', 'Analyst/Research']",
#  533: "['Marketing/PR/Advertising', 'Sales/Retail', 'Media/Journalism/Publishing']",
#  20: "['Accounting/Finance', 'Sales/Retail']",
#  405: "['IT/Software Development', 'Strategy/Consulting', 'Engineering - Telecom/Technology']",
#  286: "['Engineering - Telecom/Technology', 'Creative/Design/Art', 'Engineering - Mechanical/Electrical']",
#  717: "['Quality', 'Engineering - Mechanical/Electrical']",
#  163: "['Customer Service/Support', 'Pharmaceutical', 'R&D/Science']",
#  602: "['Operations/Management', 'Engineering - Construction/Civil/Architecture', 'Quality']",
#  430: "['Installation/Maintenance/Repair', 'Engineering - Telecom/Technology', 'Project/Program Management']",
#  629: "['Operations/Management', 'Marketing/PR/Advertising', 'Business Development']",
#  280: "['Engineering - Other', 'R&D/Science', 'Quality']",
#  667: "['Pharmaceutical']",
#  8: "['Accounting/Finance', 'Education/Teaching']",
#  147: "['Customer Service/Support', 'IT/Software Development', 'Installation/Maintenance/Repair']",
#  455: "['Logistics/Supply Chain', 'Customer Service/Support']",
#  359: "['IT/Software Development', 'Customer Service/Support', 'Business Development']",
#  504: "['Marketing/PR/Advertising', 'Creative/Design/Art', 'Sales/Retail']",
#  792: "['Sales/Retail', 'Medical/Healthcare', 'Pharmaceutical']",
#  387: "['IT/Software Development', 'Installation/Maintenance/Repair', 'Customer Service/Support']",
#  750: "['R&D/Science', 'Quality', 'Engineering - Other']",
#  175: "['Customer Service/Support', 'Strategy/Consulting', 'Sales/Retail']",
#  651: "['Pharmaceutical', 'Analyst/Research', 'Quality']",
#  483: "['Manufacturing/Production', 'Operations/Management', 'Engineering - Mechanical/Electrical']",
#  419: "['Installation/Maintenance/Repair', 'Engineering - Mechanical/Electrical', 'Engineering - Construction/Civil/Architecture']",
#  575: "['Medical/Healthcare', 'Operations/Management']",
#  421: "['Installation/Maintenance/Repair', 'Engineering - Mechanical/Electrical', 'IT/Software Development']",
#  114: "['Business Development', 'Sales/Retail', 'Project/Program Management']",
#  442: "['Installation/Maintenance/Repair', 'Operations/Management', 'Engineering - Construction/Civil/Architecture']",
#  765: "['Sales/Retail', 'Engineering - Construction/Civil/Architecture']",
#  276: "['Engineering - Other', 'Project/Program Management']",
#  289: "['Engineering - Telecom/Technology', 'Creative/Design/Art']",
#  728: "['Quality', 'Medical/Healthcare']",
#  466: "['Logistics/Supply Chain', 'Sales/Retail']",
#  517: "['Marketing/PR/Advertising', 'Media/Journalism/Publishing', 'Business Development']",
#  244: "['Engineering - Mechanical/Electrical', 'Installation/Maintenance/Repair', 'Manufacturing/Production']",
#  609: "['Operations/Management', 'Engineering - Telecom/Technology', 'IT/Software Development']",
#  524: "['Marketing/PR/Advertising', 'Medical/Healthcare', 'Sales/Retail']",
#  702: "['Purchasing/Procurement', 'Engineering - Other']",
#  492: "['Marketing/PR/Advertising', 'Administration', 'Customer Service/Support']",
#  705: "['Purchasing/Procurement', 'Logistics/Supply Chain', 'Medical/Healthcare']",
#  706: "['Purchasing/Procurement', 'Logistics/Supply Chain', 'Operations/Management']",
#  636: "['Operations/Management', 'Medical/Healthcare']",
#  749: "['R&D/Science', 'Project/Program Management', 'Pharmaceutical']",
#  101: "['Business Development', 'Marketing/PR/Advertising']",
#  25: "['Administration', 'Business Development', 'Operations/Management']",
#  727: "['Quality', 'Medical/Healthcare', 'Pharmaceutical']",
#  397: "['IT/Software Development', 'Project/Program Management', 'Installation/Maintenance/Repair']",
#  171: "['Customer Service/Support', 'Sales/Retail', 'Medical/Healthcare']",
#  742: "['R&D/Science', 'Engineering - Mechanical/Electrical', 'Manufacturing/Production']",
#  418: "['Installation/Maintenance/Repair', 'Engineering - Construction/Civil/Architecture']",
#  384: "['IT/Software Development', 'Engineering - Telecom/Technology', 'Strategy/Consulting']",
#  275: "['Engineering - Other', 'Pharmaceutical', 'Quality']",
#  441: "['Installation/Maintenance/Repair', 'Medical/Healthcare', 'R&D/Science']",
#  242: "['Engineering - Mechanical/Electrical', 'Installation/Maintenance/Repair', 'Customer Service/Support']",
#  832: "['Writing/Editorial', 'R&D/Science']",
#  220: "['Engineering - Construction/Civil/Architecture', 'Marketing/PR/Advertising', 'Business Development']",
#  598: "['Operations/Management', 'Education/Teaching', 'Training/Instructor']",
#  188: "['Education/Teaching', 'Engineering - Other']",
#  268: "['Engineering - Other', 'Education/Teaching', 'R&D/Science']",
#  662: "['Pharmaceutical', 'R&D/Science', 'Medical/Healthcare']",
#  336: "['Human Resources', 'Accounting/Finance']",
#  212: "['Engineering - Construction/Civil/Architecture', 'Engineering - Mechanical/Electrical', 'Installation/Maintenance/Repair']",
#  206: "['Engineering - Construction/Civil/Architecture', 'Administration', 'Quality']",
#  166: "['Customer Service/Support', 'Sales/Retail', 'Engineering - Construction/Civil/Architecture']",
#  500: "['Marketing/PR/Advertising', 'Business Development', 'Media/Journalism/Publishing']",
#  497: "['Marketing/PR/Advertising', 'Analyst/Research']",
#  51: "['Administration', 'Operations/Management', 'Hospitality/Hotels/Food Services']",
#  319: "['Engineering - Telecom/Technology', 'Operations/Management', 'IT/Software Development']",
#  534: "['Marketing/PR/Advertising', 'Sales/Retail', 'Medical/Healthcare']",
#  17: "['Accounting/Finance', 'Pharmaceutical']",
#  395: "['IT/Software Development', 'Project/Program Management', 'Business Development']",
#  782: "['Sales/Retail', 'Manufacturing/Production']",
#  654: "['Pharmaceutical', 'Customer Service/Support']",
#  516: "['Marketing/PR/Advertising', 'Media/Journalism/Publishing', 'Analyst/Research']",
#  459: "['Logistics/Supply Chain', 'Manufacturing/Production']",
#  620: "['Operations/Management', 'Installation/Maintenance/Repair', 'Administration']",
#  486: "['Manufacturing/Production', 'Project/Program Management', 'Engineering - Mechanical/Electrical']",
#  589: "['Operations/Management', 'Administration']",
#  291: "['Engineering - Telecom/Technology', 'Customer Service/Support', 'Sales/Retail']",
#  559: "['Media/Journalism/Publishing', 'Operations/Management']",
#  199: "['Education/Teaching', 'R&D/Science', 'Training/Instructor']",
#  650: "['Operations/Management']",
#  311: "['Engineering - Telecom/Technology', 'IT/Software Development', 'Sales/Retail']",
#  617: "['Operations/Management', 'IT/Software Development', 'Installation/Maintenance/Repair']",
#  462: "['Logistics/Supply Chain', 'Operations/Management']",
#  812: "['Training/Instructor', 'Creative/Design/Art']",
#  687: "['Project/Program Management', 'IT/Software Development', 'Writing/Editorial']",
#  496: "['Marketing/PR/Advertising', 'Analyst/Research', 'Sales/Retail']",
#  426: "['Installation/Maintenance/Repair', 'Engineering - Oil & Gas/Energy', 'Engineering - Mechanical/Electrical']",
#  648: "['Operations/Management', 'Training/Instructor']",
#  545: "['Media/Journalism/Publishing', 'Business Development', 'Sales/Retail']",
#  370: "['IT/Software Development', 'Engineering - Telecom/Technology', 'Administration']",
#  560: "['Media/Journalism/Publishing', 'Project/Program Management', 'Marketing/PR/Advertising']",
#  507: "['Marketing/PR/Advertising', 'Customer Service/Support', 'Business Development']",
#  323: "['Engineering - Telecom/Technology', 'Sales/Retail', 'Engineering - Other']",
#  73: "['Analyst/Research', 'Marketing/PR/Advertising']",
#  734: "['Quality', 'R&D/Science', 'Analyst/Research']",
#  89: "['Business Development', 'Engineering - Construction/Civil/Architecture']",
#  34: "['Administration', 'Engineering - Telecom/Technology', 'IT/Software Development']",
#  335: "['Human Resources', 'Accounting/Finance', 'Administration']",
#  117: "['Creative/Design/Art', 'Analyst/Research', 'IT/Software Development']",
#  760: "['Sales/Retail', 'Customer Service/Support', 'Business Development']",
#  458: "['Logistics/Supply Chain', 'Engineering - Other']",
#  461: "['Logistics/Supply Chain', 'Operations/Management', 'Engineering - Other']",
#  744: "['R&D/Science', 'Engineering - Other']",
#  186: "['Education/Teaching', 'Engineering - Mechanical/Electrical', 'Training/Instructor']",
#  454: "['Logistics/Supply Chain', 'Customer Service/Support', 'Sales/Retail']",
#  729: "['Quality', 'Operations/Management', 'Engineering - Mechanical/Electrical']",
#  77: "['Analyst/Research', 'Project/Program Management']",
#  304: "['Engineering - Telecom/Technology', 'IT/Software Development', 'Customer Service/Support']",
#  293: "['Engineering - Telecom/Technology', 'Education/Teaching', 'IT/Software Development']",
#  551: "['Media/Journalism/Publishing', 'Marketing/PR/Advertising', 'IT/Software Development']",
#  12: "['Accounting/Finance', 'IT/Software Development', 'Engineering - Telecom/Technology']",
#  757: "['Sales/Retail', 'Business Development', 'Marketing/PR/Advertising']",
#  385: "['IT/Software Development', 'Engineering - Telecom/Technology', 'Writing/Editorial']",
#  513: "['Marketing/PR/Advertising', 'Engineering - Telecom/Technology', 'IT/Software Development']",
#  28: "['Administration', 'Customer Service/Support', 'Operations/Management']",
#  639: "['Operations/Management', 'Project/Program Management', 'Customer Service/Support']",
#  572: "['Medical/Healthcare', 'Installation/Maintenance/Repair', 'R&D/Science']",
#  763: "['Sales/Retail', 'Customer Service/Support', 'Medical/Healthcare']",
#  273: "['Engineering - Other', 'Installation/Maintenance/Repair']",
#  59: "['Administration', 'Sales/Retail', 'Customer Service/Support']",
#  144: "['Customer Service/Support', 'Engineering - Telecom/Technology']",
#  270: "['Engineering - Other', 'Engineering - Mechanical/Electrical']",
#  94: "['Business Development', 'IT/Software Development', 'Project/Program Management']",
#  615: "['Operations/Management', 'IT/Software Development', 'Analyst/Research']",
#  70: "['Analyst/Research', 'IT/Software Development']",
#  367: "['IT/Software Development', 'Engineering - Mechanical/Electrical']",
#  317: "['Engineering - Telecom/Technology', 'Installation/Maintenance/Repair']",
#  282: "['Engineering - Other', 'R&D/Science']",
#  708: "['Purchasing/Procurement', 'Operations/Management']",
#  514: "['Marketing/PR/Advertising', 'IT/Software Development']",
#  431: "['Installation/Maintenance/Repair', 'Engineering - Telecom/Technology', 'Sales/Retail']",
#  604: "['Operations/Management', 'Engineering - Mechanical/Electrical', 'Manufacturing/Production']",
#  586: "['Operations/Management', 'Accounting/Finance']",
#  672: "['Project/Program Management', 'Business Development', 'IT/Software Development']",
#  581: "['Medical/Healthcare', 'Quality']",
#  539: "['Marketing/PR/Advertising', 'Writing/Editorial']",
#  46: "['Administration', 'Media/Journalism/Publishing', 'Marketing/PR/Advertising']",
#  140: "['Customer Service/Support', 'Engineering - Mechanical/Electrical', 'Sales/Retail']",
#  440: "['Installation/Maintenance/Repair', 'Manufacturing/Production']",
#  341: "['Human Resources', 'Operations/Management']",
#  417: "['Installation/Maintenance/Repair', 'Engineering - Construction/Civil/Architecture', 'Project/Program Management']",
#  554: "['Media/Journalism/Publishing', 'Marketing/PR/Advertising', 'Project/Program Management']",
#  107: "['Business Development', 'Project/Program Management', 'IT/Software Development']",
#  711: "['Quality', 'Analyst/Research', 'Pharmaceutical']",
#  542: "['Media/Journalism/Publishing', 'Administration']",
#  322: "['Engineering - Telecom/Technology', 'R&D/Science', 'IT/Software Development']",
#  331: "['Fashion', 'Sales/Retail']",
#  699: "['Purchasing/Procurement', 'Engineering - Construction/Civil/Architecture']",
#  58: "['Administration', 'Quality']",
#  79: "['Analyst/Research', 'R&D/Science']",
#  156: "['Customer Service/Support', 'Media/Journalism/Publishing', 'Marketing/PR/Advertising']",
#  692: "['Project/Program Management', 'Operations/Management', 'Engineering - Telecom/Technology']",
#  675: "['Project/Program Management', 'Engineering - Construction/Civil/Architecture', 'Administration']",
#  172: "['Customer Service/Support', 'Sales/Retail', 'Strategy/Consulting']",
#  561: "['Media/Journalism/Publishing', 'Tourism/Travel']",
#  26: "['Administration', 'Customer Service/Support', 'Marketing/PR/Advertising']",
#  587: "['Operations/Management', 'Administration', 'Accounting/Finance']",
#  269: "['Engineering - Other', 'Engineering - Construction/Civil/Architecture']",
#  733: "['Quality', 'Project/Program Management', 'IT/Software Development']",
#  167: "['Customer Service/Support', 'Sales/Retail', 'Engineering - Telecom/Technology']",
#  622: "['Operations/Management', 'Installation/Maintenance/Repair', 'Engineering - Telecom/Technology']",
#  512: "['Marketing/PR/Advertising', 'Engineering - Other', 'Sales/Retail']",
#  603: "['Operations/Management', 'Engineering - Construction/Civil/Architecture']",
#  495: "['Marketing/PR/Advertising', 'Analyst/Research', 'Media/Journalism/Publishing']",
#  226: "['Engineering - Construction/Civil/Architecture', 'Quality']",
#  379: "['IT/Software Development', 'Engineering - Telecom/Technology', 'Operations/Management']",
#  135: "['Creative/Design/Art', 'Sales/Retail']",
#  714: "['Quality', 'Engineering - Construction/Civil/Architecture', 'Manufacturing/Production']",
#  665: "['Pharmaceutical', 'Sales/Retail', 'Medical/Healthcare']",
#  596: "['Operations/Management', 'Customer Service/Support']",
#  822: "['Writing/Editorial', 'Education/Teaching', 'Medical/Healthcare']",
#  393: "['IT/Software Development', 'Operations/Management']",
#  141: "['Customer Service/Support', 'Engineering - Mechanical/Electrical']",
#  669: "['Project/Program Management', 'Administration', 'Engineering - Other']",
#  668: "['Project/Program Management', 'Accounting/Finance']",
#  716: "['Quality', 'Engineering - Mechanical/Electrical', 'Manufacturing/Production']",
#  804: "['Sports and Leisure', 'Education/Teaching']",
#  798: "['Sales/Retail', 'Pharmaceutical']",
#  494: "['Marketing/PR/Advertising', 'Administration']",
#  601: "['Operations/Management', 'Engineering - Construction/Civil/Architecture', 'Installation/Maintenance/Repair']",
#  390: "['IT/Software Development', 'Marketing/PR/Advertising', 'Media/Journalism/Publishing']",
#  815: "['Training/Instructor', 'Engineering - Telecom/Technology', 'IT/Software Development']",
#  74: "['Analyst/Research', 'Media/Journalism/Publishing', 'Marketing/PR/Advertising']",
#  580: "['Medical/Healthcare', 'Pharmaceutical', 'Sales/Retail']",
#  190: "['Education/Teaching', 'IT/Software Development', 'Engineering - Telecom/Technology']",
#  239: "['Engineering - Mechanical/Electrical', 'Engineering - Telecom/Technology', 'IT/Software Development']",
#  530: "['Marketing/PR/Advertising', 'Project/Program Management']",
#  681: "['Project/Program Management', 'Engineering - Other']",
#  537: "['Marketing/PR/Advertising', 'Training/Instructor']",
#  164: "['Customer Service/Support', 'Pharmaceutical']",
#  83: "['Business Development', 'Administration', 'Operations/Management']",
#  169: "['Customer Service/Support', 'Sales/Retail', 'IT/Software Development']",
#  693: "['Project/Program Management', 'Operations/Management']",
#  182: "['Education/Teaching', 'Analyst/Research', 'Creative/Design/Art']",
#  519: "['Marketing/PR/Advertising', 'Media/Journalism/Publishing', 'Engineering - Construction/Civil/Architecture']",
#  211: "['Engineering - Construction/Civil/Architecture', 'Customer Service/Support']",
#  422: "['Installation/Maintenance/Repair', 'Engineering - Mechanical/Electrical', 'Manufacturing/Production']",
#  48: "['Administration', 'Medical/Healthcare']",
#  443: "['Installation/Maintenance/Repair', 'Operations/Management', 'Engineering - Mechanical/Electrical']",
#  641: "['Operations/Management', 'Project/Program Management', 'Engineering - Telecom/Technology']",
#  710: "['Quality', 'Administration', 'Engineering - Construction/Civil/Architecture']",
#  277: "['Engineering - Other', 'Purchasing/Procurement']",
#  299: "['Engineering - Telecom/Technology', 'Engineering - Other', 'IT/Software Development']",
#  625: "['Operations/Management', 'Logistics/Supply Chain', 'Purchasing/Procurement']",
#  87: "['Business Development', 'Customer Service/Support', 'Sales/Retail']",
#  235: "['Engineering - Mechanical/Electrical', 'Customer Service/Support', 'Installation/Maintenance/Repair']",
#  490: "['Manufacturing/Production', 'R&D/Science', 'Engineering - Other']",
#  198: "['Education/Teaching', 'Quality']",
#  683: "['Project/Program Management', 'Hospitality/Hotels/Food Services', 'Operations/Management']",
#  187: "['Education/Teaching', 'Engineering - Other', 'R&D/Science']",
#  649: "['Operations/Management', 'Writing/Editorial']",
#  818: "['Training/Instructor', 'Medical/Healthcare', 'Education/Teaching']",
#  735: "['Quality', 'R&D/Science', 'Manufacturing/Production']",
#  4: "['Accounting/Finance', 'Business Development']",
#  312: "['Engineering - Telecom/Technology', 'IT/Software Development', 'Writing/Editorial']",
#  505: "['Marketing/PR/Advertising', 'Creative/Design/Art', 'Writing/Editorial']",
#  22: "['Accounting/Finance', 'Strategy/Consulting']",
#  468: "['Manufacturing/Production', 'Creative/Design/Art', 'Engineering - Mechanical/Electrical']",
#  202: "['Education/Teaching', 'Training/Instructor', 'R&D/Science']",
#  691: "['Project/Program Management', 'Marketing/PR/Advertising']",
#  439: "['Installation/Maintenance/Repair', 'Manufacturing/Production', 'Engineering - Mechanical/Electrical']",
#  168: "['Customer Service/Support', 'Sales/Retail', 'Hospitality/Hotels/Food Services']",
#  684: "['Project/Program Management', 'IT/Software Development', 'Customer Service/Support']",
#  43: "['Administration', 'Logistics/Supply Chain']",
#  329: "['Fashion', 'Creative/Design/Art', 'Sales/Retail']",
#  6: "['Accounting/Finance', 'Customer Service/Support', 'IT/Software Development']",
#  730: "['Quality', 'Operations/Management', 'Manufacturing/Production']",
#  616: "['Operations/Management', 'IT/Software Development', 'Engineering - Telecom/Technology']",
#  221: "['Engineering - Construction/Civil/Architecture', 'Marketing/PR/Advertising']",
#  128: "['Creative/Design/Art', 'Manufacturing/Production']",
#  325: "['Engineering - Telecom/Technology', 'Sales/Retail', 'Installation/Maintenance/Repair']",
#  736: "['Quality', 'R&D/Science', 'Pharmaceutical']",
#  543: "['Media/Journalism/Publishing', 'Analyst/Research', 'Marketing/PR/Advertising']",
#  797: "['Sales/Retail', 'Pharmaceutical', 'Engineering - Other']",
#  570: "['Medical/Healthcare', 'Engineering - Other', 'Sales/Retail']",
#  343: "['IT/Software Development', 'Accounting/Finance', 'Customer Service/Support']",
#  697: "['Purchasing/Procurement', 'Administration', 'Operations/Management']",
#  802: "['Sales/Retail', 'Training/Instructor']",
#  278: "['Engineering - Other', 'Quality']",
#  191: "['Education/Teaching', 'IT/Software Development', 'Training/Instructor']",
#  104: "['Business Development', 'Medical/Healthcare', 'Sales/Retail']",
#  605: "['Operations/Management', 'Engineering - Mechanical/Electrical', 'Sales/Retail']",
#  637: "['Operations/Management', 'Pharmaceutical', 'Administration']",
#  527: "['Marketing/PR/Advertising', 'Operations/Management', 'Sales/Retail']",
#  382: "['IT/Software Development', 'Engineering - Telecom/Technology', 'R&D/Science']",
#  63: "['Analyst/Research', 'Customer Service/Support']",
#  238: "['Engineering - Mechanical/Electrical', 'Engineering - Other']",
#  597: "['Operations/Management', 'Education/Teaching', 'Administration']",
#  337: "['Human Resources', 'Administration']",
#  81: "['Banking', 'Accounting/Finance']",
#  748: "['R&D/Science', 'Pharmaceutical', 'Sales/Retail']",
#  647: "['Operations/Management', 'Strategy/Consulting']",
#  217: "['Engineering - Construction/Civil/Architecture', 'Engineering - Telecom/Technology', 'Installation/Maintenance/Repair']",
#  612: "['Operations/Management', 'Engineering - Telecom/Technology']",
#  32: "['Administration', 'Engineering - Construction/Civil/Architecture', 'Engineering - Mechanical/Electrical']",
#  825: "['Writing/Editorial', 'Marketing/PR/Advertising', 'Creative/Design/Art']",
#  720: "['Quality', 'Engineering - Other', 'R&D/Science']",
#  696: "['Purchasing/Procurement', 'Administration', 'Installation/Maintenance/Repair']",
#  608: "['Operations/Management', 'Engineering - Other']",
#  152: "['Customer Service/Support', 'Logistics/Supply Chain']",
#  355: "['IT/Software Development', 'Business Development', 'Engineering - Telecom/Technology']",
# ...
#  44: "['Administration', 'Marketing/PR/Advertising', 'Sales/Retail']",
#  590: "['Operations/Management', 'Analyst/Research', 'Administration']",
#  474: "['Manufacturing/Production', 'Engineering - Other', 'Quality']",
#  577: "['Medical/Healthcare', 'Pharmaceutical', 'Customer Service/Support']",
#  448: "['Legal', 'Administration']",
#  193: "['Education/Teaching', 'Marketing/PR/Advertising', 'Media/Journalism/Publishing']",
#  340: "['Human Resources', 'Manufacturing/Production']",
#  327: "['Engineering - Telecom/Technology', 'Training/Instructor', 'IT/Software Development']",
#  558: "['Media/Journalism/Publishing', 'Operations/Management', 'Business Development']",
#  593: "['Operations/Management', 'Customer Service/Support', 'Administration']",
#  153: "['Customer Service/Support', 'Marketing/PR/Advertising', 'Business Development']",
#  595: "['Operations/Management', 'Customer Service/Support', 'Sales/Retail']",
#  789: "['Sales/Retail', 'Media/Journalism/Publishing', 'Business Development']",
#  478: "['Manufacturing/Production', 'Human Resources']",
#  627: "['Operations/Management', 'Manufacturing/Production', 'Engineering - Mechanical/Electrical']",
#  783: "['Sales/Retail', 'Marketing/PR/Advertising', 'Administration']",
#  236: "['Engineering - Mechanical/Electrical', 'Engineering - Construction/Civil/Architecture']",
#  674: "['Project/Program Management', 'Customer Service/Support']",
#  423: "['Installation/Maintenance/Repair', 'Engineering - Mechanical/Electrical', 'Project/Program Management']",
#  9: "['Accounting/Finance', 'Engineering - Telecom/Technology', 'IT/Software Development']",
#  576: "['Medical/Healthcare', 'Pharmaceutical', 'Administration']",
#  464: "['Logistics/Supply Chain', 'Purchasing/Procurement', 'Human Resources']",
#  179: "['Education/Teaching', 'Accounting/Finance']",
#  820: "['Training/Instructor', 'Sales/Retail']",
#  754: "['Sales/Retail', 'Administration']",
#  686: "['Project/Program Management', 'IT/Software Development', 'Installation/Maintenance/Repair']",
#  640: "['Operations/Management', 'Project/Program Management', 'Engineering - Construction/Civil/Architecture']",
#  567: "['Medical/Healthcare', 'Customer Service/Support', 'Sales/Retail']",
#  525: "['Marketing/PR/Advertising', 'Medical/Healthcare']",
#  632: "['Operations/Management', 'Marketing/PR/Advertising', 'Medical/Healthcare']",
#  433: "['Installation/Maintenance/Repair', 'IT/Software Development', 'Customer Service/Support']",
#  819: "['Training/Instructor', 'Operations/Management', 'Education/Teaching']",
#  41: "['Administration', 'Legal', 'Accounting/Finance']",
#  779: "['Sales/Retail', 'Installation/Maintenance/Repair', 'Engineering - Telecom/Technology']",
#  491: "['Manufacturing/Production']",
#  302: "['Engineering - Telecom/Technology', 'IT/Software Development', 'Business Development']",
#  361: "['IT/Software Development', 'Customer Service/Support', 'Project/Program Management']",
#  642: "['Operations/Management', 'Project/Program Management']",
#  11: "['Accounting/Finance', 'Human Resources']",
#  148: "['Customer Service/Support', 'IT/Software Development', 'Project/Program Management']",
#  652: "['Pharmaceutical', 'Analyst/Research', 'R&D/Science']",
#  552: "['Media/Journalism/Publishing', 'Marketing/PR/Advertising', 'Medical/Healthcare']",
#  732: "['Quality', 'Pharmaceutical', 'Manufacturing/Production']",
#  563: "['Media/Journalism/Publishing', 'Writing/Editorial', 'Medical/Healthcare']",
#  248: "['Engineering - Mechanical/Electrical', 'Manufacturing/Production', 'Installation/Maintenance/Repair']",
#  630: "['Operations/Management', 'Marketing/PR/Advertising', 'IT/Software Development']",
#  209: "['Engineering - Construction/Civil/Architecture', 'Creative/Design/Art', 'Manufacturing/Production']",
#  591: "['Operations/Management', 'Analyst/Research', 'IT/Software Development']",
#  453: "['Logistics/Supply Chain', 'Analyst/Research']",
#  756: "['Sales/Retail', 'Business Development', 'IT/Software Development']",
#  233: "['Engineering - Mechanical/Electrical', 'Creative/Design/Art', 'Manufacturing/Production']",
#  31: "['Administration', 'Education/Teaching']",
#  569: "['Medical/Healthcare', 'Education/Teaching', 'Writing/Editorial']",
#  446: "['Installation/Maintenance/Repair', 'Project/Program Management', 'Engineering - Mechanical/Electrical']",
#  457: "['Logistics/Supply Chain', 'Engineering - Other', 'Manufacturing/Production']",
#  809: "['Tourism/Travel', 'Operations/Management']",
#  740: "['R&D/Science', 'Education/Teaching', 'Writing/Editorial']",
#  332: "['Hospitality/Hotels/Food Services', 'Operations/Management']",
#  49: "['Administration', 'Operations/Management', 'Analyst/Research']",
#  330: "['Fashion', 'Logistics/Supply Chain', 'Purchasing/Procurement']",
#  437: "['Installation/Maintenance/Repair', 'IT/Software Development', 'Project/Program Management']",
#  671: "['Project/Program Management', 'Analyst/Research']",
#  222: "['Engineering - Construction/Civil/Architecture', 'Operations/Management', 'C-Level Executive/GM/Director']",
#  553: "['Media/Journalism/Publishing', 'Marketing/PR/Advertising', 'Operations/Management']",
#  93: "['Business Development', 'IT/Software Development', 'Engineering - Telecom/Technology']",
#  265: "['Engineering - Other', 'Analyst/Research']",
#  346: "['IT/Software Development', 'Analyst/Research', 'Accounting/Finance']",
#  511: "['Marketing/PR/Advertising', 'Engineering - Mechanical/Electrical', 'Sales/Retail']",
#  92: "['Business Development', 'IT/Software Development', 'Customer Service/Support']",
#  628: "['Operations/Management', 'Manufacturing/Production']",
#  786: "['Sales/Retail', 'Marketing/PR/Advertising', 'Engineering - Mechanical/Electrical']",
#  47: "['Administration', 'Medical/Healthcare', 'Pharmaceutical']",
#  159: "['Customer Service/Support', 'Medical/Healthcare']",
#  356: "['IT/Software Development', 'Business Development', 'Sales/Retail']",
#  767: "['Sales/Retail', 'Engineering - Mechanical/Electrical', 'Engineering - Other']",
#  18: "['Accounting/Finance', 'Project/Program Management']",
#  579: "['Medical/Healthcare', 'Pharmaceutical', 'R&D/Science']",
#  158: "['Customer Service/Support', 'Medical/Healthcare', 'Pharmaceutical']",
#  621: "['Operations/Management', 'Installation/Maintenance/Repair', 'Engineering - Mechanical/Electrical']",
#  535: "['Marketing/PR/Advertising', 'Sales/Retail', 'Operations/Management']",
#  793: "['Sales/Retail', 'Medical/Healthcare', 'R&D/Science']",
#  726: "['Quality', 'Manufacturing/Production']",
#  392: "['IT/Software Development', 'Operations/Management', 'Engineering - Telecom/Technology']",
#  362: "['IT/Software Development', 'Customer Service/Support', 'Sales/Retail']",
#  791: "['Sales/Retail', 'Medical/Healthcare', 'Customer Service/Support']",
#  810: "['Tourism/Travel', 'Sales/Retail', 'Customer Service/Support']",
#  197: "['Education/Teaching', 'Pharmaceutical', 'Writing/Editorial']",
#  245: "['Engineering - Mechanical/Electrical', 'Installation/Maintenance/Repair', 'Project/Program Management']",
#  184: "['Education/Teaching', 'Business Development', 'Operations/Management']",
#  407: "['IT/Software Development', 'Training/Instructor']",
#  39: "['Administration', 'Installation/Maintenance/Repair', 'Purchasing/Procurement']",
#  227: "['Engineering - Construction/Civil/Architecture', 'Sales/Retail', 'Customer Service/Support']",
#  613: "['Operations/Management', 'Hospitality/Hotels/Food Services']",
#  738: "['Quality', 'Training/Instructor', 'Education/Teaching']",
#  109: "['Business Development', 'Project/Program Management']",
#  154: "['Customer Service/Support', 'Marketing/PR/Advertising', 'Media/Journalism/Publishing']",
#  463: "['Logistics/Supply Chain', 'Purchasing/Procurement', 'Engineering - Mechanical/Electrical']",
#  607: "['Operations/Management', 'Engineering - Other', 'Logistics/Supply Chain']",
#  704: "['Purchasing/Procurement', 'Logistics/Supply Chain', 'Engineering - Mechanical/Electrical']",
#  588: "['Operations/Management', 'Administration', 'Medical/Healthcare']",
#  655: "['Pharmaceutical', 'IT/Software Development']",
#  402: "['IT/Software Development', 'Sales/Retail', 'Customer Service/Support']",
#  718: "['Quality', 'Engineering - Other', 'Engineering - Mechanical/Electrical']",
#  805: "['Strategy/Consulting', 'Accounting/Finance']",
#  314: "['Engineering - Telecom/Technology', 'Installation/Maintenance/Repair', 'Engineering - Mechanical/Electrical']",
#  611: "['Operations/Management', 'Engineering - Telecom/Technology', 'Quality']",
#  436: "['Installation/Maintenance/Repair', 'IT/Software Development', 'Operations/Management']",
#  485: "['Manufacturing/Production', 'Pharmaceutical', 'Project/Program Management']",
#  780: "['Sales/Retail', 'Logistics/Supply Chain', 'Engineering - Construction/Civil/Architecture']",
#  124: "['Creative/Design/Art', 'Engineering - Telecom/Technology']",
#  661: "['Pharmaceutical', 'R&D/Science', 'Analyst/Research']",
#  830: "['Writing/Editorial', 'Medical/Healthcare', 'Media/Journalism/Publishing']",
#  300: "['Engineering - Telecom/Technology', 'IT/Software Development', 'Accounting/Finance']",
#  214: "['Engineering - Construction/Civil/Architecture', 'Engineering - Oil & Gas/Energy', 'Sales/Retail']",
#  113: "['Business Development', 'Sales/Retail', 'Operations/Management']",
#  139: "['Customer Service/Support', 'Engineering - Mechanical/Electrical', 'Installation/Maintenance/Repair']",
#  623: "['Operations/Management', 'Installation/Maintenance/Repair', 'IT/Software Development']",
#  416: "['Installation/Maintenance/Repair', 'Engineering - Construction/Civil/Architecture', 'Engineering - Mechanical/Electrical']",
#  266: "['Engineering - Other', 'Creative/Design/Art', 'Engineering - Construction/Civil/Architecture']",
#  105: "['Business Development', 'Operations/Management', 'Marketing/PR/Advertising']",
#  247: "['Engineering - Mechanical/Electrical', 'Logistics/Supply Chain']",
#  288: "['Engineering - Telecom/Technology', 'Creative/Design/Art', 'Manufacturing/Production']",
#  145: "['Customer Service/Support', 'IT/Software Development', 'Accounting/Finance']",
#  664: "['Pharmaceutical', 'Sales/Retail', 'Marketing/PR/Advertising']",
#  161: "['Customer Service/Support', 'Operations/Management', 'Sales/Retail']",
#  241: "['Engineering - Mechanical/Electrical', 'IT/Software Development', 'Sales/Retail']",
#  470: "['Manufacturing/Production', 'Engineering - Mechanical/Electrical', 'Creative/Design/Art']",
#  254: "['Engineering - Mechanical/Electrical', 'Project/Program Management', 'Quality']",
#  294: "['Engineering - Telecom/Technology', 'Engineering - Construction/Civil/Architecture', 'Installation/Maintenance/Repair']",
#  487: "['Manufacturing/Production', 'Project/Program Management', 'Pharmaceutical']",
#  658: "['Pharmaceutical', 'Project/Program Management', 'R&D/Science']",
#  173: "['Customer Service/Support', 'Sales/Retail', 'Tourism/Travel']",
#  78: "['Analyst/Research', 'Quality', 'IT/Software Development']",
#  618: "['Operations/Management', 'IT/Software Development', 'Strategy/Consulting']",
#  257: "['Engineering - Mechanical/Electrical', 'Quality']",
#  460: "['Logistics/Supply Chain', 'Operations/Management', 'Administration']",
#  295: "['Engineering - Telecom/Technology', 'Engineering - Mechanical/Electrical', 'Creative/Design/Art']",
#  472: "['Manufacturing/Production', 'Engineering - Mechanical/Electrical', 'Sales/Retail']",
#  249: "['Engineering - Mechanical/Electrical', 'Manufacturing/Production', 'Quality']",
#  469: "['Manufacturing/Production', 'Engineering - Construction/Civil/Architecture', 'Creative/Design/Art']",
#  216: "['Engineering - Construction/Civil/Architecture', 'Engineering - Telecom/Technology', 'IT/Software Development']",
#  232: "['Engineering - Mechanical/Electrical', 'Business Development']",
#  824: "['Writing/Editorial', 'IT/Software Development', 'Engineering - Telecom/Technology']",
#  318: "['Engineering - Telecom/Technology', 'Manufacturing/Production', 'Creative/Design/Art']",
#  281: "['Engineering - Other', 'R&D/Science', 'Sales/Retail']",
#  808: "['Tourism/Travel', 'Customer Service/Support']",
#  578: "['Medical/Healthcare', 'Pharmaceutical', 'Quality']",
#  768: "['Sales/Retail', 'Engineering - Mechanical/Electrical', 'Engineering - Telecom/Technology']",
#  333: "['Hospitality/Hotels/Food Services', 'Sales/Retail', 'Customer Service/Support']",
#  694: "['Project/Program Management', 'Pharmaceutical', 'R&D/Science']",
#  338: "['Human Resources', 'C-Level Executive/GM/Director']",
#  811: "['Tourism/Travel']",
#  488: "['Manufacturing/Production', 'Quality', 'Operations/Management']",
#  653: "['Pharmaceutical', 'Customer Service/Support', 'Medical/Healthcare']",
#  434: "['Installation/Maintenance/Repair', 'IT/Software Development', 'Engineering - Mechanical/Electrical']",
#  271: "['Engineering - Other', 'IT/Software Development', 'Project/Program Management']",
#  261: "['Engineering - Oil & Gas/Energy', 'Customer Service/Support', 'Sales/Retail']",
#  568: "['Medical/Healthcare', 'Customer Service/Support']",
#  27: "['Administration', 'Customer Service/Support', 'Medical/Healthcare']",
#  86: "['Business Development', 'Customer Service/Support', 'Marketing/PR/Advertising']",
#  566: "['Medical/Healthcare', 'Customer Service/Support', 'Pharmaceutical']",
#  262: "['Engineering - Oil & Gas/Energy', 'Engineering - Mechanical/Electrical', 'Sales/Retail']",
#  831: "['Writing/Editorial', 'Quality', 'Customer Service/Support']",
#  772: "['Sales/Retail', 'Engineering - Telecom/Technology', 'Operations/Management']",
#  799: "['Sales/Retail', 'Project/Program Management', 'Medical/Healthcare']",
#  645: "['Operations/Management', 'Sales/Retail', 'Customer Service/Support']",
#  703: "['Purchasing/Procurement', 'Installation/Maintenance/Repair', 'Administration']",
#  592: "['Operations/Management', 'Creative/Design/Art']",
#  477: "['Manufacturing/Production', 'Engineering - Telecom/Technology', 'IT/Software Development']",
#  471: "['Manufacturing/Production', 'Engineering - Mechanical/Electrical', 'Installation/Maintenance/Repair']",
#  364: "['IT/Software Development', 'Education/Teaching']",
#  90: "['Business Development', 'Engineering - Telecom/Technology', 'IT/Software Development']",
#  574: "['Medical/Healthcare', 'Media/Journalism/Publishing', 'Writing/Editorial']",
#  218: "['Engineering - Construction/Civil/Architecture', 'Installation/Maintenance/Repair', 'Engineering - Mechanical/Electrical']",
#  761: "['Sales/Retail', 'Customer Service/Support', 'Hospitality/Hotels/Food Services']",
#  635: "['Operations/Management', 'Medical/Healthcare', 'Project/Program Management']",
#  409: "['IT/Software Development', 'Writing/Editorial']",
#  801: "['Sales/Retail', 'Tourism/Travel']",
#  228: "['Engineering - Construction/Civil/Architecture', 'Sales/Retail', 'Engineering - Mechanical/Electrical']",
#  606: "['Operations/Management', 'Engineering - Mechanical/Electrical']",
#  529: "['Marketing/PR/Advertising', 'Pharmaceutical', 'Sales/Retail']",
#  482: "['Manufacturing/Production', 'Marketing/PR/Advertising']",
#  142: "['Customer Service/Support', 'Engineering - Other', 'IT/Software Development']",
#  272: "['Engineering - Other', 'Installation/Maintenance/Repair', 'Operations/Management']",
#  386: "['IT/Software Development', 'Installation/Maintenance/Repair', 'Business Development']",
#  411: "['Installation/Maintenance/Repair', 'Administration', 'Purchasing/Procurement']",
#  38: "['Administration', 'Installation/Maintenance/Repair', 'Operations/Management']",
#  571: "['Medical/Healthcare', 'Hospitality/Hotels/Food Services']",
#  656: "['Pharmaceutical', 'Manufacturing/Production']",
#  85: "['Business Development', 'Customer Service/Support', 'IT/Software Development']",
#  207: "['Engineering - Construction/Civil/Architecture', 'Administration']",
#  3: "['Accounting/Finance', 'Banking']",
#  348: "['IT/Software Development', 'Analyst/Research', 'Creative/Design/Art']",
#  807: "['Tourism/Travel', 'Customer Service/Support', 'Sales/Retail']",
#  36: "['Administration', 'IT/Software Development', 'Engineering - Telecom/Technology']",
#  42: "['Administration', 'Legal']"}

# %% [markdown]
# __Then__ here we Binary Encode all the integer targets

# %%
labels = to_categorical(labels)

# %% [markdown]
# After that, We are going to use the train_test_split function of the sckiti learn to split the dataset.

# %%
jobs_train, jobs_test, labels_train, labels_test = train_test_split(train_data, labels, test_size=0.25, random_state=500)

# %% [markdown]
# From here we start vectorizing the features of both training and testing datasets

# %%
vectorizer_train = CountVectorizer()
vectorizer_train.fit(jobs_train)

jobs_train = vectorizer_train.transform(jobs_train)
jobs_test  = vectorizer_train.transform(jobs_test)

# %% [markdown]
# ### start building our model
#
# Our dataset is not huge, So 2 dense layers are enough for training our dataset without having extreme overfitting.

# %%
input_dim = jobs_train.shape[1]  # Number of features
number_of_classes = jobs_data.jobFunction.nunique()


model = Sequential()
model.add(layers.Dense(1024, input_dim=input_dim, activation='relu'))
model.add(layers.Dense(number_of_classes, activation='sigmoid'))
# Out:
# WARNING:tensorflow:From /home/ahmed/ml/env/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.compile(loss='binary_crossentropy', 
               optimizer='adam', 
               metrics=['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              1143808
# _________________________________________________________________
# dense_2 (Dense)              (None, 835)               855875
# =================================================================
# Total params: 1,999,683
# Trainable params: 1,999,683
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping

es = EarlyStopping(monitor='loss', mode='min',patience=10)
history = model.fit(jobs_train, labels_train,epochs=50,batch_size=10, callbacks=[es])
# Out:
# WARNING:tensorflow:From /home/ahmed/ml/env/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/50
# 8152/8152 [==============================] - 30s 4ms/step - loss: 0.0253 - acc: 0.9977
# Epoch 2/50
# 8152/8152 [==============================] - 29s 4ms/step - loss: 0.0039 - acc: 0.9993
# Epoch 3/50
# 8152/8152 [==============================] - 26s 3ms/step - loss: 0.0031 - acc: 0.9993
# Epoch 4/50
# 8152/8152 [==============================] - 27s 3ms/step - loss: 0.0026 - acc: 0.9994
# Epoch 5/50
# 8152/8152 [==============================] - 27s 3ms/step - loss: 0.0022 - acc: 0.9994
# Epoch 6/50
# 8152/8152 [==============================] - 27s 3ms/step - loss: 0.0019 - acc: 0.9994
# Epoch 7/50
# 8152/8152 [==============================] - 26s 3ms/step - loss: 0.0017 - acc: 0.9994
# Epoch 8/50
# 8152/8152 [==============================] - 26s 3ms/step - loss: 0.0016 - acc: 0.9995
# Epoch 9/50
# 8152/8152 [==============================] - 26s 3ms/step - loss: 0.0015 - acc: 0.9995
# Epoch 10/50
# 8152/8152 [==============================] - 26s 3ms/step - loss: 0.0014 - acc: 0.9995
# Epoch 11/50
# 8152/8152 [==============================] - 26s 3ms/step - loss: 0.0014 - acc: 0.9995
# Epoch 12/50
# 8152/8152 [==============================] - 26s 3ms/step - loss: 0.0013 - acc: 0.9995
# Epoch 13/50
# 8152/8152 [==============================] - 27s 3ms/step - loss: 0.0013 - acc: 0.9995
# Epoch 14/50
# 8152/8152 [==============================] - 27s 3ms/step - loss: 0.0013 - acc: 0.9995
# Epoch 15/50
# 8152/8152 [==============================] - 28s 3ms/step - loss: 0.0012 - acc: 0.9995
# Epoch 16/50
# 8152/8152 [==============================] - 27s 3ms/step - loss: 0.0012 - acc: 0.9995
# Epoch 17/50
# 8152/8152 [==============================] - 27s 3ms/step - loss: 0.0012 - acc: 0.9995
# Epoch 18/50
# 8152/8152 [==============================] - 27s 3ms/step - loss: 0.0012 - acc: 0.9995
# Epoch 19/50
# 8152/8152 [==============================] - 27s 3ms/step - loss: 0.0012 - acc: 0.9995
# Epoch 20/50
# 8152/8152 [==============================] - 26s 3ms/step - loss: 0.0012 - acc: 0.9995
# Epoch 21/50
# 8152/8152 [==============================] - 27s 3ms/step - loss: 0.0011 - acc: 0.9995
# Epoch 22/50
# 8152/8152 [==============================] - 27s 3ms/step - loss: 0.0011 - acc: 0.9995
# Epoch 23/50
# 8152/8152 [==============================] - 30s 4ms/step - loss: 0.0011 - acc: 0.9995
# Epoch 24/50
# 8152/8152 [==============================] - 30s 4ms/step - loss: 0.0011 - acc: 0.9995
# Epoch 25/50
# 8152/8152 [==============================] - 30s 4ms/step - loss: 0.0011 - acc: 0.9995
# Epoch 26/50
# 8152/8152 [==============================] - 30s 4ms/step - loss: 0.0011 - acc: 0.9995
# Epoch 27/50
# 8152/8152 [==============================] - 29s 4ms/step - loss: 0.0011 - acc: 0.9995
# Epoch 28/50
# 8152/8152 [==============================] - 31s 4ms/step - loss: 0.0011 - acc: 0.9995
# Epoch 29/50
# 8152/8152 [==============================] - 30s 4ms/step - loss: 0.0011 - acc: 0.9995
# Epoch 30/50
# 8152/8152 [==============================] - 27s 3ms/step - loss: 0.0011 - acc: 0.9995
# Epoch 31/50
# 8152/8152 [==============================] - 27s 3ms/step - loss: 0.0011 - acc: 0.9995
# Epoch 32/50
# 8152/8152 [==============================] - 27s 3ms/step - loss: 0.0011 - acc: 0.9995
# Epoch 33/50
# 8152/8152 [==============================] - 28s 3ms/step - loss: 0.0011 - acc: 0.9995
# Epoch 34/50
# 8152/8152 [==============================] - 29s 3ms/step - loss: 0.0011 - acc: 0.9995
# Epoch 35/50
# 8152/8152 [==============================] - 29s 4ms/step - loss: 0.0011 - acc: 0.9995
# Epoch 36/50
# 8152/8152 [==============================] - 28s 3ms/step - loss: 0.0011 - acc: 0.9995
# Epoch 37/50
# 8152/8152 [==============================] - 28s 3ms/step - loss: 0.0011 - acc: 0.9995
# Epoch 38/50
# 8152/8152 [==============================] - 28s 3ms/step - loss: 0.0011 - acc: 0.9995
# Epoch 39/50
# 8152/8152 [==============================] - 28s 3ms/step - loss: 0.0011 - acc: 0.9995
# Epoch 40/50
# 8152/8152 [==============================] - 28s 3ms/step - loss: 0.0010 - acc: 0.9995
# Epoch 41/50
# 8152/8152 [==============================] - 28s 3ms/step - loss: 0.0010 - acc: 0.9995
# Epoch 42/50
# 8152/8152 [==============================] - 27s 3ms/step - loss: 0.0010 - acc: 0.9995
# Epoch 43/50
# 8152/8152 [==============================] - 27s 3ms/step - loss: 0.0010 - acc: 0.9996
# Epoch 44/50
# 8152/8152 [==============================] - 27s 3ms/step - loss: 0.0010 - acc: 0.9995
# Epoch 45/50
# 8152/8152 [==============================] - 28s 3ms/step - loss: 0.0010 - acc: 0.9995
# Epoch 46/50
# 8152/8152 [==============================] - 28s 3ms/step - loss: 0.0010 - acc: 0.9996
# Epoch 47/50
# 8152/8152 [==============================] - 28s 3ms/step - loss: 0.0010 - acc: 0.9995
# Epoch 48/50
# 8152/8152 [==============================] - 28s 3ms/step - loss: 0.0010 - acc: 0.9995
# Epoch 49/50
# 8152/8152 [==============================] - 28s 3ms/step - loss: 0.0010 - acc: 0.9996
# Epoch 50/50
# 8152/8152 [==============================] - 28s 3ms/step - loss: 0.0010 - acc: 0.9996

# %%
loss, accuracy = model.evaluate(jobs_train, labels_train, verbose=False)
print("Training Accuracy: {:.4f}".format(accuracy))
loss, accuracy = model.evaluate(jobs_test, labels_test, verbose=False)
print("Testing Accuracy:  {:.4f}".format(accuracy))
# Out:
# Training Accuracy: 0.9996
# Testing Accuracy:  0.9993

# %% [markdown]
# In order to test our testing dataset accordig to the approach of Keywords list we have followed, We need to follow some steps
#
# 1. We have to inspect each title in the dataset,
# 2. check whether it includes any words that belongs to any of the the 3 lists,
# 3. if yes, change the title into the assigned title of the List, otherwise don't change it
# 4. Vectorize the final result( As we dont' have a pipeline this time)
# 5. apply the model on the final result(binary encoded result)
# 6. decode the model prediction (integer result)
# 7. Map the decoded prediction into it's text value

# %%
def decode(datum):
    return np.argmax(datum)

def JobFunction(job):
    Software_exist = False
    Sales_exist = False
    Marketing_exist = False

    words = job.split()
    for word in words:
        word = word.lower()
    
        if word in Sales_Keywords:
            Sales_exist = True
            break
        if word in Marketing_Keywords:
            Marketing_exist =True
            break
        if word in Software_Keywords:
            Software_exist =True
            break 
    if Software_exist:    
        job= "Software Developer"
    if Sales_exist:
        job= "Sales Consultant"
    if Marketing_exist:
        job= "Marketing Specialist"
    
    job = vectorizer_train.transform([job])
    final_result = model.predict(job)
    decoded_datum = decode(final_result)
    return Map[decoded_datum]

# %%
print(JobFunction('Medical doctor'))
print(JobFunction('php developer'))
print(JobFunction('social media specialist'))
print(JobFunction('Real Estate agent'))
# Out:
# ['Medical/Healthcare']
# ['Engineering - Telecom/Technology', 'IT/Software Development']
# ['Media/Journalism/Publishing', 'Marketing/PR/Advertising']
# ['Sales/Retail']

# %% [markdown]
# Here we are going to save all the arrays/models/values that we are going to use for thr APIs call

# %%
model.save('final_keras_jobs_model.h5')

Sales_Keywords = np.array(Sales_Keywords)
Marketing_Keywords =np.array(Marketing_Keywords)
Software_Keywords = np.array(Software_Keywords)
Map_np = np.array(Map)


np.save('Sales_keywords.npy',Sales_Keywords)
np.save('Marekting_keywords.npy',Marketing_Keywords)
np.save('Software_keywords.npy',Software_Keywords)
np.save('Map.npy',Map_np)

pickle.dump(vectorizer_train, open("jobs_data_vectorizer.pickel", "wb"))

# %%
#finish
